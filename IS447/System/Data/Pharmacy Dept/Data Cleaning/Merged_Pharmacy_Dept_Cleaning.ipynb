# %% [markdown]
# # Pharmacy Department
#
# Includes PEH, GEH, MEH, MNH

# %%
import pandas as pd
import numpy as np

# %%
PEH = pd.read_csv('./PEH_CLEANED_Data.csv')
GEH = pd.read_csv('./GEH TTO TAT (cleaned).csv')
MEH = pd.read_csv('./MEH_CLEANED_Data.csv')
MNH = pd.read_csv('./MNH TTO TAT (cleaned).csv')

# %% [markdown]
# ## Assigning 'Hospital' Name as indicator

# %%
#PEH
PEH['Hospital'] = 'PEH'

# %%
PEH.head()
# Out:
#          Date Ward  Room Case Number Time TTO Received Time (Meds Sent Down)  \
# 0  2021-03-15   4A  4825   302100869          13:50:00                   NaN
# 1  2021-11-05   4B  4606   302101606          08:35:00                   NaN
# 2  2021-08-26   3A  3841   302102993          12:32:00                   NaN
# 3  2021-03-10   3A  3838   302103523          11:37:00                   NaN
# 4  2021-10-16   3B  3616   302103680          09:19:00                   NaN
#
#   Time TTO Checked Time (Counselled)                       Remarks  \
# 0         13:53:00               NaN
# 1         08:49:00          09:00:00  Please help fill in PML Data
# 2         12:39:00               NaN
# 3         11:43:00               NaN
# 4         09:39:00               NaN
#
#   Checked By (Pharmacist)  ... Bedside Counselling Candidate Dispensed by  \
# 0                    CHAR  ...                            No          NaN
# ...

# %%
PEH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3246 entries, 0 to 3245
# Data columns (total 23 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Date                                                          3245 non-null   object
#  1   Ward                                                          3231 non-null   object
#  2   Room                                                          3237 non-null   object
#  3   Case Number                                                   3238 non-null   object
#  4   Time TTO Received                                             3242 non-null   object
#  5   Time (Meds Sent Down)                                         313 non-null    object
#  6   Time TTO Checked                                              3243 non-null   object
# ...

# %%
#GEH
GEH['Hospital'] = 'GEH'

# %%
GEH.head()
# Out:
#          Date   Case Number Room Number Ward TTO Type No. of Drugs  \
# 0  2021-04-01  1.021023e+09         957   9W      SCM            2
# 1  2021-04-01  1.021023e+09         509   5E      SCM            3
# 2  2021-04-01  1.021023e+09         508   5E      SCM            4
# 3  2021-04-01  1.021023e+09         932   9E      SCM            2
# 4  2021-04-01  1.021023e+09         909   9E      SCM            5
#
#   Time TTO Received Time TTO Checked Checked by Time TTO Reached  \
# 0          08:59:00         09:04:00        LET         09:29:00
# 1          09:05:00         09:26:00        LET         09:29:00
# 2          09:07:00         09:19:00        LET         09:32:00
# 3          09:11:00         09:22:00      ELISE         09:37:00
# 4          09:36:00         10:02:00      ELISE         10:21:00
#
#   Time TTO Counselled Counselled by Remarks   Weekday  \
# 0            09:35:00           LET     NaN  Thursday
# 1            09:32:00         ELISE     NaN  Thursday
# ...

# %%
GEH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2803 entries, 0 to 2802
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2803 non-null   object
#  1   Case Number                2803 non-null   float64
#  2   Room Number                2803 non-null   object
#  3   Ward                       491 non-null    object
#  4   TTO Type                   2794 non-null   object
#  5   No. of Drugs               2800 non-null   object
#  6   Time TTO Received          2803 non-null   object
#  7   Time TTO Checked           2779 non-null   object
#  8   Checked by                 466 non-null    object
#  9   Time TTO Reached           2742 non-null   object
#  10  Time TTO Counselled        2699 non-null   object
#  11  Counselled by              420 non-null    object
#  12  Remarks                    572 non-null    object
# ...

# %%
#MEH
MEH['Hospital'] = 'MEH'

# %%
MEH.head()
# Out:
#   Time TTO Checked Time (Dispensed) Time (Dispensing) Time TTO Received  \
# 0         08:25:00         08:46:00          08:45:00          08:02:00
# 1         08:29:00         08:56:00          08:46:00          08:28:00
# 2         09:02:00         09:42:00          09:05:00          08:44:00
# 3         08:54:00         11:09:00          11:08:00          08:45:00
# 4         09:01:00              NaN               NaN          08:48:00
#
#       Ward         Case Number Time (in Pharmacy) Time (in Pigeon)  \
# 0        7  2021029472-20e1d00                NaN              NaN
# 1       5A  2021028679-f2da14a                NaN              NaN
# 2       4B  2021029518-31da567                NaN              NaN
# 3       4A  2021026492-a1686aa           09:42:00              NaN
# 4  Dayward  2021029372-898d040                NaN         09:02:00
#
#   Time (Dispensed by Nurse) Time (Passed to Nurse)        Date   Weekday  \
# ...

# %%
MEH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11635 entries, 0 to 11634
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time TTO Checked           11570 non-null  object
#  1   Time (Dispensed)           5955 non-null   object
#  2   Time (Dispensing)          6149 non-null   object
#  3   Time TTO Received          11635 non-null  object
#  4   Ward                       11635 non-null  object
#  5   Case Number                11635 non-null  object
#  6   Time (in Pharmacy)         2233 non-null   object
#  7   Time (in Pigeon)           5430 non-null   object
#  8   Time (Dispensed by Nurse)  960 non-null    object
#  9   Time (Passed to Nurse)     281 non-null    object
#  10  Date                       11635 non-null  object
#  11  Weekday                    11635 non-null  object
#  12  Time TTO Dispensed         11541 non-null  object
# ...

# %%
#MNH
MNH['Hospital'] = 'MNH'

# %%
MNH.head()
# Out:
#          Date Bed Number Case Number  No. of Drugs  \
# 0  2021-01-01        905  4020095917           4.0
# 1  2021-01-01       1202  4020097017           8.0
# 2  2021-01-01       1224  4020095632           1.0
# 3  2021-01-01        818  4020097033           1.0
# 4  2021-01-01        803  4020097026           1.0
#
#   Comments (for delayed cases) (eg. Pt sleeping etc)  \
# 0                                                NaN
# 1                                    wait for 2nd rx
# 2                                                NaN
# 3                                                NaN
# 4  can close, added on metformin and glipizide. 1...
#
#   Time Taken To Pack (mins) Time Taken to Reach Pt (mins) Time TTO Received  \
# 0                       PBH                          0:12          08:28:00
# 1                       PBH                           NaN          09:04:00
# 2                      0:04                          0:19          09:01:00
# ...

# %%
MNH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15513 entries, 0 to 15512
# Data columns (total 19 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Date                                                15513 non-null  object
#  1   Bed Number                                          15504 non-null  object
#  2   Case Number                                         15508 non-null  object
#  3   No. of Drugs                                        15511 non-null  float64
#  4   Comments (for delayed cases) (eg. Pt sleeping etc)  3854 non-null   object
#  5   Time Taken To Pack (mins)                           15475 non-null  object
#  6   Time Taken to Reach Pt (mins)                       15503 non-null  object
#  7   Time TTO Received                                   15513 non-null  object
# ...

# %% [markdown]
# ## Merge ALL relevant CSV(s)

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.concat([PEH,GEH,MEH,MNH], ignore_index=True)

df
# Out:
#              Date Ward  Room Case Number Time TTO Received  \
# 0      2021-03-15   4A  4825   302100869          13:50:00
# 1      2021-11-05   4B  4606   302101606          08:35:00
# 2      2021-08-26   3A  3841   302102993          12:32:00
# 3      2021-03-10   3A  3838   302103523          11:37:00
# 4      2021-10-16   3B  3616   302103680          09:19:00
# ...           ...  ...   ...         ...               ...
# 33192  2021-12-31  NaN   NaN  4021107656          13:00:00
# 33193  2021-12-31  NaN   NaN  4021107518          13:35:00
# 33194  2021-12-31  NaN   NaN  4021107644          14:08:00
# 33195  2021-12-31  NaN   NaN  4021108689          13:59:00
# 33196  2021-12-31  NaN   NaN  4021108267          16:20:00
#
#       Time (Meds Sent Down) Time TTO Checked Time (Counselled)  \
# 0                       NaN         13:53:00               NaN
# 1                       NaN         08:49:00          09:00:00
# 2                       NaN         12:39:00               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33197 entries, 0 to 33196
# Data columns (total 44 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Date                                                          33196 non-null  object
#  1   Ward                                                          15357 non-null  object
#  2   Room                                                          3237 non-null   object
#  3   Case Number                                                   33184 non-null  object
#  4   Time TTO Received                                             33193 non-null  object
#  5   Time (Meds Sent Down)                                         313 non-null    object
#  6   Time TTO Checked                                              17592 non-null  object
# ...

# %%
df[df['Date'].isnull()]
# Out:
#      Date Ward  Room Case Number Time TTO Received Time (Meds Sent Down)  \
# 2190  NaN   4B  4609  3021031272          10:01:00                   NaN
#
#      Time TTO Checked Time (Counselled)                       Remarks  \
# 2190         10:15:00          10:25:00  Please help fill in PML Data
#
#      Checked By (Pharmacist) Time Taken (Ready for Collection)  \
# 2190                     SSM                          00:14:00
#
#      Time Taken (to Counselling) No. of Drugs Bedside Counselling Candidate  \
# 2190                    00:24:00            3                           Yes
#
#      Dispensed by PML given?  \
# 2190           AT        YES
#
#      If not given, WHY?! If given, were any interventions needed? Weekday  \
# 2190                                                 NO               NaN
#
#      Time TTO Dispensed  Overall Time Taken (mins) Meet KPI Office Hours  \
# 2190           10:25:00                       24.0      Yes          Yes
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                                                                1
# Ward                                                            17840
# Room                                                            29960
# Case Number                                                        13
# Time TTO Received                                                   4
# Time (Meds Sent Down)                                           32884
# Time TTO Checked                                                15605
# Time (Counselled)                                               32204
# Remarks                                                         30211
# Checked By (Pharmacist)                                         29960
# Time Taken (Ready for Collection)                               29959
# Time Taken (to Counselling)                                     32208
# No. of Drugs                                                    13901
# ...
