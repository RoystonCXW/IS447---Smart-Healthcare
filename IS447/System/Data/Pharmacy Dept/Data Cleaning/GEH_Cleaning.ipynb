# %% [markdown]
# # GEH Pharmacy Department

# %%
import pandas as pd
import numpy as np
import glob
import os
from datetime import *

# %% [markdown]
# ## Merge April & May Data

# %%
files_xls_1 = ['../GEH TTO Data/GEH TTO TAT (April 2021).xlsx', '../GEH TTO Data/GEH TTO TAT 2021 May.xlsx']

# %%
df = pd.DataFrame()

# %%
for f in files_xls_1:
    data = pd.read_excel(f, 'Template')
    df = df.append(data)

# %%
df
# Out:
#              Verifier/Typist  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                      Date      Case No    Room No       Ward
# 1        2021-04-01 00:00:00  1021023186        957         9W
# 2        2021-04-01 00:00:00  1021023191        509         5E
# 3        2021-04-01 00:00:00  1021023190        508         5E
# 4        2021-04-01 00:00:00  1021023367        932         9E
# ...                      ...         ...        ...        ...
# 1048570                  NaN         NaN        NaN        NaN
# 1048571                  NaN         NaN        NaN        NaN
# 1048572                  NaN         NaN        NaN        NaN
# 1048573                  NaN         NaN        NaN        NaN
# 1048574                  NaN         NaN        NaN        NaN
#
#                      Unnamed: 4    Unnamed: 5          Unnamed: 6  \
# 0        SCM / Handwritten TTO   No. of items  Time in / Verified
# 1                           SCM             2            08:59:00
# 2                           SCM             3            09:05:00
# 3                           SCM             4            09:07:00
# 4                           SCM             2            09:11:00
# ...                         ...           ...                 ...
# 1048570                     NaN           NaN                 NaN
# 1048571                     NaN           NaN                 NaN
# 1048572                     NaN           NaN                 NaN
# 1048573                     NaN           NaN                 NaN
# 1048574                     NaN           NaN                 NaN
#
#               Checker  Unnamed: 8    Unnamed: 9  ... Unnamed: 20 Unnamed: 21  \
# 0        Time checked  Checked by  Time to meet  ...         NaN         NaN
# 1            09:04:00         LET      09:44:00  ...         NaN         NaN
# 2            09:26:00         LET      09:50:00  ...         NaN         NaN
# 3            09:19:00         LET      09:52:00  ...         NaN         NaN
# 4            09:22:00       ELISE      09:56:00  ...         NaN         NaN
# ...               ...         ...           ...  ...         ...         ...
# 1048570           NaN         NaN      00:45:00  ...         NaN         NaN
# 1048571           NaN         NaN      00:45:00  ...         NaN         NaN
# 1048572           NaN         NaN      00:45:00  ...         NaN         NaN
# 1048573           NaN         NaN      00:45:00  ...         NaN         NaN
# 1048574           NaN         NaN      00:45:00  ...         NaN         NaN
#
#         Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0               NaN         NaN         NaN         NaN         NaN
# 1               NaN         NaN         NaN         NaN         NaN
# 2               NaN         NaN         NaN         NaN         NaN
# 3               NaN         NaN         NaN         NaN         NaN
# 4               NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 1048570         NaN         NaN         NaN         NaN         NaN
# 1048571         NaN         NaN         NaN         NaN         NaN
# 1048572         NaN         NaN         NaN         NaN         NaN
# 1048573         NaN         NaN         NaN         NaN         NaN
# 1048574         NaN         NaN         NaN         NaN         NaN
#
#         Unnamed: 27  Unnamed: 28  Unnamed: 29
# 0               NaN          NaN          NaN
# 1               NaN          NaN          NaN
# 2               NaN          NaN          NaN
# 3               NaN          NaN          NaN
# 4               NaN          NaN          NaN
# ...             ...          ...          ...
# 1048570         NaN          NaN          NaN
# 1048571         NaN          NaN          NaN
# 1048572         NaN          NaN          NaN
# 1048573         NaN          NaN          NaN
# 1048574         NaN          NaN          NaN
#
# [2097150 rows x 30 columns]

# %%
df.columns = df.iloc[0]

# %%
df = df.drop(0)
df
# Out:
# 0                      Date      Case No Room No Ward SCM / Handwritten TTO   \
# 1        2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 2        2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 3        2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 4        2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 5        2021-04-01 00:00:00  1021023455     909   9E                    SCM
# ...                      ...         ...     ...  ...                    ...
# 1048570                  NaN         NaN     NaN  NaN                    NaN
# 1048571                  NaN         NaN     NaN  NaN                    NaN
# 1048572                  NaN         NaN     NaN  NaN                    NaN
# 1048573                  NaN         NaN     NaN  NaN                    NaN
# 1048574                  NaN         NaN     NaN  NaN                    NaN
#
# 0       No. of items Time in / Verified Time checked Checked by Time to meet  \
# 1                  2           08:59:00     09:04:00        LET     09:44:00
# 2                  3           09:05:00     09:26:00        LET     09:50:00
# 3                  4           09:07:00     09:19:00        LET     09:52:00
# 4                  2           09:11:00     09:22:00      ELISE     09:56:00
# 5                  5           09:36:00     10:02:00      ELISE     10:21:00
# ...              ...                ...          ...        ...          ...
# 1048570          NaN                NaN          NaN        NaN     00:45:00
# 1048571          NaN                NaN          NaN        NaN     00:45:00
# 1048572          NaN                NaN          NaN        NaN     00:45:00
# 1048573          NaN                NaN          NaN        NaN     00:45:00
# 1048574          NaN                NaN          NaN        NaN     00:45:00
#
# 0        ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1        ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2        ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3        ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4        ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5        ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...      ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1048570  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1048571  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1048572  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1048573  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1048574  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [2097148 rows x 30 columns]

# %%
df = df.dropna(axis=1, how='all')
df
# Out:
# 0                      Date      Case No Room No Ward SCM / Handwritten TTO   \
# 1        2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 2        2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 3        2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 4        2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 5        2021-04-01 00:00:00  1021023455     909   9E                    SCM
# ...                      ...         ...     ...  ...                    ...
# 1048570                  NaN         NaN     NaN  NaN                    NaN
# 1048571                  NaN         NaN     NaN  NaN                    NaN
# 1048572                  NaN         NaN     NaN  NaN                    NaN
# 1048573                  NaN         NaN     NaN  NaN                    NaN
# 1048574                  NaN         NaN     NaN  NaN                    NaN
#
# 0       No. of items Time in / Verified Time checked Checked by Time to meet  \
# 1                  2           08:59:00     09:04:00        LET     09:44:00
# 2                  3           09:05:00     09:26:00        LET     09:50:00
# 3                  4           09:07:00     09:19:00        LET     09:52:00
# 4                  2           09:11:00     09:22:00      ELISE     09:56:00
# 5                  5           09:36:00     10:02:00      ELISE     10:21:00
# ...              ...                ...          ...        ...          ...
# 1048570          NaN                NaN          NaN        NaN     00:45:00
# 1048571          NaN                NaN          NaN        NaN     00:45:00
# 1048572          NaN                NaN          NaN        NaN     00:45:00
# 1048573          NaN                NaN          NaN        NaN     00:45:00
# 1048574          NaN                NaN          NaN        NaN     00:45:00
#
# 0       Time reached   Time Counselled Counselled by Remarks Limo Service   \
# 1            09:29:00         09:35:00           LET     NaN           NaN
# 2            09:29:00         09:32:00         ELISE     NaN           NaN
# 3            09:32:00         10:17:00         ELISE       P           NaN
# 4            09:37:00         09:40:00           LET     NaN           NaN
# 5            10:21:00         10:25:00         ELISE     NaN           NaN
# ...               ...              ...           ...     ...           ...
# 1048570           NaN              NaN           NaN     NaN           NaN
# 1048571           NaN              NaN           NaN     NaN           NaN
# 1048572           NaN              NaN           NaN     NaN           NaN
# 1048573           NaN              NaN           NaN     NaN           NaN
# 1048574           NaN              NaN           NaN     NaN           NaN
#
# 0       Timings (Checked) Timings (Reached)  NaN
# 1                00:05:00          00:30:00  NaN
# 2                00:21:00          00:24:00  NaN
# 3                00:12:00          00:25:00  NaN
# 4                00:11:00          00:26:00  NaN
# 5                00:26:00          00:45:00  NaN
# ...                   ...               ...  ...
# 1048570               NaN               NaN  NaN
# 1048571               NaN               NaN  NaN
# 1048572               NaN               NaN  NaN
# 1048573               NaN               NaN  NaN
# 1048574               NaN               NaN  NaN
#
# [2097148 rows x 18 columns]

# %%
df = df[pd.notnull(df['Case No'])]

# %%
df
# Out:
# 0                  Date      Case No Room No Ward SCM / Handwritten TTO   \
# 1    2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 2    2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 3    2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 4    2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 5    2021-04-01 00:00:00  1021023455     909   9E                    SCM
# ..                   ...         ...     ...  ...                    ...
# 203                  NaN  1021037723     112  10W                    SCM
# 204                  NaN  1021037197     921   9E                    SCM
# 205                  NaN  1021037427     101  10W                    SCM
# 206                  NaN  1021039189     928   9E                    scm
# 207                  NaN  1021038490     622   TU                    SCM
#
# 0   No. of items Time in / Verified Time checked Checked by Time to meet  \
# 1              2           08:59:00     09:04:00        LET     09:44:00
# 2              3           09:05:00     09:26:00        LET     09:50:00
# 3              4           09:07:00     09:19:00        LET     09:52:00
# 4              2           09:11:00     09:22:00      ELISE     09:56:00
# 5              5           09:36:00     10:02:00      ELISE     10:21:00
# ..           ...                ...          ...        ...          ...
# 203            2           09:24:00     10:53:00        TEL     10:09:00
# 204            1           10:38:00     10:53:00        TEL     11:23:00
# 205            1           12:00:00     12:05:00        TEL     12:45:00
# 206            3           12:57:00     13:22:00         WQ     13:42:00
# 207           13           11:05:00     13:15:00         WQ     11:50:00
#
# 0   Time reached   Time Counselled Counselled by                 Remarks  \
# 1        09:29:00         09:35:00           LET                     NaN
# 2        09:29:00         09:32:00         ELISE                     NaN
# 3        09:32:00         10:17:00         ELISE                       P
# 4        09:37:00         09:40:00           LET                     NaN
# 5        10:21:00         10:25:00         ELISE                     NaN
# ..            ...              ...           ...                     ...
# 203      11:10:00         11:17:00           TEL          patient shower
# 204      11:15:00              NaN           TEL   Patient not available
# 205      12:10:00         12:20:00           TEL                     NaN
# 206      13:40:00         13:47:00           TEL                     NaN
# 207      13:25:00         13:39:00           TEL  waiting for clinic TTO
#
# 0   Limo Service  Timings (Checked) Timings (Reached)  NaN
# 1             NaN          00:05:00          00:30:00  NaN
# 2             NaN          00:21:00          00:24:00  NaN
# 3             NaN          00:12:00          00:25:00  NaN
# 4             NaN          00:11:00          00:26:00  NaN
# 5             NaN          00:26:00          00:45:00  NaN
# ..            ...               ...               ...  ...
# 203           NaN          01:29:00          01:46:00  NaN
# 204           NaN          00:15:00          00:37:00  NaN
# 205           NaN          00:05:00          00:10:00  NaN
# 206           NaN          00:25:00          00:43:00  NaN
# 207           NaN          02:10:00          02:20:00  NaN
#
# [497 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497 entries, 1 to 207
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    424 non-null    object
#  1   Case No                 497 non-null    object
#  2   Room No                 497 non-null    object
#  3   Ward                    497 non-null    object
#  4   SCM / Handwritten TTO   497 non-null    object
#  5   No. of items            497 non-null    object
#  6   Time in / Verified      491 non-null    object
#  7   Time checked            471 non-null    object
#  8   Checked by              471 non-null    object
#  9   Time to meet            497 non-null    object
#  10  Time reached            434 non-null    object
#  11   Time Counselled        390 non-null    object
#  12  Counselled by           423 non-null    object
#  13  Remarks                 154 non-null    object
#  14  Limo Service            1 non-null      object
#  15  Timings (Checked)       489 non-null    object
#  16  Timings (Reached)       486 non-null    object
#  17  nan                     0 non-null      object
# dtypes: object(18)
# memory usage: 73.8+ KB

# %% [markdown]
# ### Drop columns

# %%
df2= df.copy()

# %%
df2 = df2.drop(df.iloc[:, 17:], axis=1)

# %%
#reset index 
df2 = df2.reset_index(drop=True)

# %% [markdown]
# ### Rename common columns

# %%
df2.rename({'Date ': 'Date', 
            'Case No': 'Case Number', 
            'Room No': 'Room Number',
            'SCM / Handwritten TTO ': 'TTO Type', 
            'No. of items':'No. of Drugs', 
            'Time in / Verified': 'Time TTO Received', # the start time
            'Time checked':'Time TTO Checked', 
            'Time reached ': 'Time TTO Reached', # the end time 
            ' Time Counselled':'Time TTO Counselled', # end time if patients need to be counselled
           'Limo Service ':'Limo Service'},  
           axis=1, inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 424 non-null    object
#  1   Case Number          497 non-null    object
#  2   Room Number          497 non-null    object
#  3   Ward                 497 non-null    object
#  4   TTO Type             497 non-null    object
#  5   No. of Drugs         497 non-null    object
#  6   Time TTO Received    491 non-null    object
#  7   Time TTO Checked     471 non-null    object
#  8   Checked by           471 non-null    object
#  9   Time to meet         497 non-null    object
#  10  Time TTO Reached     434 non-null    object
#  11  Time TTO Counselled  390 non-null    object
#  12  Counselled by        423 non-null    object
#  13  Remarks              154 non-null    object
#  14  Limo Service         1 non-null      object
#  15  Timings (Checked)    489 non-null    object
#  16  Timings (Reached)    486 non-null    object
# dtypes: object(17)
# memory usage: 66.1+ KB

# %% [markdown]
# ### Handle missing value

# %%
list(df2.columns)
# Out:
# ['Date',
#  'Case Number',
#  'Room Number',
#  'Ward',
#  'TTO Type',
#  'No. of Drugs',
#  'Time TTO Received',
#  'Time TTO Checked',
#  'Checked by',
#  'Time to meet',
#  'Time TTO Reached',
#  'Time TTO Counselled',
#  'Counselled by',
#  'Remarks',
#  'Limo Service',
#  'Timings (Checked)',
#  'Timings (Reached)']

# %%
df2.isnull().sum()
# Out:
# 0
# Date                    73
# Case Number              0
# Room Number              0
# Ward                     0
# TTO Type                 0
# No. of Drugs             0
# Time TTO Received        6
# Time TTO Checked        26
# Checked by              26
# Time to meet             0
# Time TTO Reached        63
# Time TTO Counselled    107
# Counselled by           74
# Remarks                343
# Limo Service           496
# Timings (Checked)        8
# Timings (Reached)       11
# dtype: int64

# %% [markdown]
# #### Missing date

# %%
# change to datetime formate
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
missing_date = df2[df2['Date'].isnull()]
missing_date
# Out:
# 0   Date Case Number Room Number Ward TTO Type No. of Drugs Time TTO Received  \
# 386  NaT  1021035404         609   6E      SCM            3          09:10:00
# 387  NaT  1021033687         919   9E      SCM            6          09:21:00
# 388  NaT  1021032404         228  10W      SCM            3          09:33:00
# 389  NaT  1021034765         916   9E      SCM            4          09:35:00
# 390  NaT  1021035355         755   7W      SCM            2          09:41:00
# ..   ...         ...         ...  ...      ...          ...               ...
# 492  NaT  1021037723         112  10W      SCM            2          09:24:00
# 493  NaT  1021037197         921   9E      SCM            1          10:38:00
# 494  NaT  1021037427         101  10W      SCM            1          12:00:00
# 495  NaT  1021039189         928   9E      scm            3          12:57:00
# 496  NaT  1021038490         622   TU      SCM           13          11:05:00
#
# 0   Time TTO Checked Checked by Time to meet Time TTO Reached  \
# 386         09:22:00      HEMIN     09:55:00         09:52:00
# 387         09:39:00      HEMIN     10:06:00         11:02:00
# 388         10:10:00        LJY     10:18:00         10:40:00
# 389         09:43:00      HEMIN     10:20:00         10:00:00
# 390         09:51:00        LJY     10:26:00              NaN
# ..               ...        ...          ...              ...
# 492         10:53:00        TEL     10:09:00         11:10:00
# 493         10:53:00        TEL     11:23:00         11:15:00
# 494         12:05:00        TEL     12:45:00         12:10:00
# 495         13:22:00         WQ     13:42:00         13:40:00
# 496         13:15:00         WQ     11:50:00         13:25:00
#
# 0   Time TTO Counselled Counselled by                 Remarks Limo Service  \
# 386            09:55:00         HEMIN                     NaN          NaN
# 387            11:09:00           LJY                     NaN          NaN
# 388            10:44:00         HEMIN                     NaN          NaN
# 389            10:04:00           AKH                     NaN          NaN
# 390                 NaN           NaN            WAIT FOR SON          NaN
# ..                  ...           ...                     ...          ...
# 492            11:17:00           TEL          patient shower          NaN
# 493                 NaN           TEL   Patient not available          NaN
# 494            12:20:00           TEL                     NaN          NaN
# 495            13:47:00           TEL                     NaN          NaN
# 496            13:39:00           TEL  waiting for clinic TTO          NaN
#
# 0   Timings (Checked)    Timings (Reached)
# 386          00:12:00             00:42:00
# 387          00:18:00             01:41:00
# 388          00:37:00             01:07:00
# 389          00:08:00             00:25:00
# 390          00:10:00  1899-12-30 14:19:00
# ..                ...                  ...
# 492          01:29:00             01:46:00
# 493          00:15:00             00:37:00
# 494          00:05:00             00:10:00
# 495          00:25:00             00:43:00
# 496          02:10:00             02:20:00
#
# [73 rows x 17 columns]

# %%
# fill up missing date based on previous known value 
df2['Date'] = df2['Date'].fillna(method='ffill')
df2.tail()
# Out:
# 0         Date Case Number Room Number Ward TTO Type No. of Drugs  \
# 492 2021-05-31  1021037723         112  10W      SCM            2
# 493 2021-05-31  1021037197         921   9E      SCM            1
# 494 2021-05-31  1021037427         101  10W      SCM            1
# 495 2021-05-31  1021039189         928   9E      scm            3
# 496 2021-05-31  1021038490         622   TU      SCM           13
#
# 0   Time TTO Received Time TTO Checked Checked by Time to meet  \
# 492          09:24:00         10:53:00        TEL     10:09:00
# 493          10:38:00         10:53:00        TEL     11:23:00
# 494          12:00:00         12:05:00        TEL     12:45:00
# 495          12:57:00         13:22:00         WQ     13:42:00
# 496          11:05:00         13:15:00         WQ     11:50:00
#
# 0   Time TTO Reached Time TTO Counselled Counselled by  \
# 492         11:10:00            11:17:00           TEL
# 493         11:15:00                 NaN           TEL
# 494         12:10:00            12:20:00           TEL
# 495         13:40:00            13:47:00           TEL
# 496         13:25:00            13:39:00           TEL
#
# 0                   Remarks Limo Service Timings (Checked) Timings (Reached)
# 492          patient shower          NaN          01:29:00          01:46:00
# 493   Patient not available          NaN          00:15:00          00:37:00
# 494                     NaN          NaN          00:05:00          00:10:00
# 495                     NaN          NaN          00:25:00          00:43:00
# 496  waiting for clinic TTO          NaN          02:10:00          02:20:00

# %% [markdown]
# #### Missing Time TTO Received

# %%
# drop the one missing row in april dataset bc no time in cant calculate time taken
# drop row in may too for same reason
df2 = df2.dropna(subset=['Time TTO Received'])

# %%
df2.isnull().sum()
# Out:
# 0
# Date                     0
# Case Number              0
# Room Number              0
# Ward                     0
# TTO Type                 0
# No. of Drugs             0
# Time TTO Received        0
# Time TTO Checked        24
# Checked by              25
# Time to meet             0
# Time TTO Reached        60
# Time TTO Counselled    104
# Counselled by           71
# Remarks                340
# Limo Service           490
# Timings (Checked)        8
# Timings (Reached)       11
# dtype: int64

# %% [markdown]
# ### EDA

# %%
df2
# Out:
# 0         Date Case Number Room Number Ward TTO Type No. of Drugs  \
# 0   2021-04-01  1021023186         957   9W      SCM            2
# 1   2021-04-01  1021023191         509   5E      SCM            3
# 2   2021-04-01  1021023190         508   5E      SCM            4
# 3   2021-04-01  1021023367         932   9E      SCM            2
# 4   2021-04-01  1021023455         909   9E      SCM            5
# ..         ...         ...         ...  ...      ...          ...
# 492 2021-05-31  1021037723         112  10W      SCM            2
# 493 2021-05-31  1021037197         921   9E      SCM            1
# 494 2021-05-31  1021037427         101  10W      SCM            1
# 495 2021-05-31  1021039189         928   9E      scm            3
# 496 2021-05-31  1021038490         622   TU      SCM           13
#
# 0   Time TTO Received Time TTO Checked Checked by Time to meet  \
# 0            08:59:00         09:04:00        LET     09:44:00
# 1            09:05:00         09:26:00        LET     09:50:00
# 2            09:07:00         09:19:00        LET     09:52:00
# 3            09:11:00         09:22:00      ELISE     09:56:00
# 4            09:36:00         10:02:00      ELISE     10:21:00
# ..                ...              ...        ...          ...
# 492          09:24:00         10:53:00        TEL     10:09:00
# 493          10:38:00         10:53:00        TEL     11:23:00
# 494          12:00:00         12:05:00        TEL     12:45:00
# 495          12:57:00         13:22:00         WQ     13:42:00
# 496          11:05:00         13:15:00         WQ     11:50:00
#
# 0   Time TTO Reached Time TTO Counselled Counselled by  \
# 0           09:29:00            09:35:00           LET
# 1           09:29:00            09:32:00         ELISE
# 2           09:32:00            10:17:00         ELISE
# 3           09:37:00            09:40:00           LET
# 4           10:21:00            10:25:00         ELISE
# ..               ...                 ...           ...
# 492         11:10:00            11:17:00           TEL
# 493         11:15:00                 NaN           TEL
# 494         12:10:00            12:20:00           TEL
# 495         13:40:00            13:47:00           TEL
# 496         13:25:00            13:39:00           TEL
#
# 0                   Remarks Limo Service Timings (Checked) Timings (Reached)
# 0                       NaN          NaN          00:05:00          00:30:00
# 1                       NaN          NaN          00:21:00          00:24:00
# 2                         P          NaN          00:12:00          00:25:00
# 3                       NaN          NaN          00:11:00          00:26:00
# 4                       NaN          NaN          00:26:00          00:45:00
# ..                      ...          ...               ...               ...
# 492          patient shower          NaN          01:29:00          01:46:00
# 493   Patient not available          NaN          00:15:00          00:37:00
# 494                     NaN          NaN          00:05:00          00:10:00
# 495                     NaN          NaN          00:25:00          00:43:00
# 496  waiting for clinic TTO          NaN          02:10:00          02:20:00
#
# [491 rows x 17 columns]

# %% [markdown]
# #### Day of Week

# %%
df2['Weekday'] = df2['Date'].dt.day_name()

# %%
# handle Unknown string format: 9.:09 in Time TTO reached
df2['Time TTO Reached'] = df2['Time TTO Reached'].replace('9.:09', 'NA')

# %%
#tto_received = pd.to_datetime(df2['Time TTO Received'].astype(str)) 
#tto_reached = pd.to_datetime(df2[df2['Time TTO Reached'] != 'NA']['Time TTO Reached'].astype(str))
#tto_counselled = pd.to_datetime(df2[df2['Time TTO Counselled'] != 'NA']['Time TTO Counselled'].astype(str))

#df2['Overall Time Taken (mins)'] = tto_reached.sub(tto_received).dt.total_seconds().div(60)

# %%
#df2.info()

# %%
#df2['time_diff'] = pd.Timestamp(df2['Time TTO Received']) - pd.Timestamp(df['end_time'])   
#def f(row):
#    if row['Time TTO Counselled'] != " ":
#        val = tto_counselled.sub(tto_received).dt.total_seconds().div(60)
    #elif row['Time TTO Counselled'] <  row['Time TTO Reached']:
    #    val = tto_reached.sub(tto_received).dt.total_seconds().div(60)
#    else:
#        val = tto_reached.sub(tto_received).dt.total_seconds().div(60)
#    return val

# %%
#df2['Overall Time Taken (mins)_2'] = df2.apply(f, axis=1)
#df2

# %% [markdown]
# ### Export to CSV for Final Merge

# %%
df2.to_csv("GEH TTO TAT (April-May 2021).csv", index = False, header=True)

# %% [markdown]
# ## Merge remaining months

# %%
files_xls_2 = ['../GEH TTO Data/GEH TTO TAT 2021 June.xlsx',
 '../GEH TTO Data/GEH TTO TAT 2021 July.xlsx',
 '../GEH TTO Data/GEH TTO TAT 2021 Aug.xlsx',
'../GEH TTO Data/GEH TTO TAT 2021 Sep.xlsx',
 '../GEH TTO Data/GEH TTO TAT 2021 Nov.xlsx', 
'../GEH TTO Data/GEH TTO TAT 2021 Oct.xlsx', 
 '../GEH TTO Data/GEH TTO TAT 2021 Dec.xlsx']

# %%
df3 = pd.DataFrame()
for f in files_xls_2:
    data = pd.read_excel(f)
    df3 = df3.append(data)
df3
# Out:
#                    Date   Case Number Room TTO Type  No. of Items  \
# 0   2021-06-01 01:00:00  1.021039e+09  953      SCM           3.0
# 1   2021-06-01 01:00:00  1.021039e+09  623      SCM           1.0
# 2   2021-06-01 01:00:00  1.021039e+09  757      SCM           1.0
# 3   2021-06-01 01:00:00  1.021038e+09  916      SCM           4.0
# 4   2021-06-01 01:00:00  1.021039e+09  958      NaN           NaN
# ..                  ...           ...  ...      ...           ...
# 324 2021-12-01 00:00:00  1.021086e+09  905      SCM           9.0
# 325 2021-12-01 00:00:00  1.021087e+09  102      SCM           1.0
# 326 2021-12-01 00:00:00  1.021085e+09  113      SCM           1.0
# 327 2021-12-01 00:00:00  1.021085e+09  113      SCM           1.0
# 328 2021-12-01 00:00:00  1.021085e+09  113      SCM           8.0
#
#                 Time In        Time Checked       Pharmacist_Checked  \
# 0   2021-06-01 09:13:00 2021-06-01 09:07:17              Ray Hng Yeo
# 1   2021-06-01 09:30:00 2021-06-01 09:38:25              Ray Hng Yeo
# 2   2021-06-01 09:36:00 2021-06-01 09:43:48  Nur Shahida Binte Ahmad
# 3   2021-06-01 09:46:00 2021-06-01 09:49:54  Nur Shahida Binte Ahmad
# 4   2021-06-01 08:55:00 2021-06-01 09:56:00                 Wan Qing
# ..                  ...                 ...                      ...
# 324 2021-12-01 09:39:00 2021-12-01 10:30:00              Hemin Chang
# 325 2021-12-01 11:30:00 2021-12-01 11:42:00            Zhao Wan Qing
# 326 2021-12-01 12:26:00 2021-12-01 12:38:00            Zhao Wan Qing
# 327 2021-12-01 13:11:00 2021-12-01 13:17:00              Yi Zhen Tay
# 328                 NaT                 NaT                      NaN
#
#            Time Reached      Time Dispensed  ... status_TTOReached  \
# 0   2021-06-01 09:28:26 2021-06-01 09:31:37  ...              True
# 1   2021-06-01 10:07:32 2021-06-01 10:09:24  ...              True
# 2   2021-06-01 10:30:09 2021-06-01 10:30:18  ...              True
# 3   2021-06-01 10:12:22 2021-06-01 10:13:34  ...              True
# 4   2021-06-01 10:18:00                 NaT  ...              True
# ..                  ...                 ...  ...               ...
# 324 2021-12-01 10:44:00 2021-12-01 10:50:00  ...               Yes
# 325 2021-12-01 12:08:00 2021-12-01 12:12:00  ...               Yes
# 326 2021-12-01 12:45:00                 NaT  ...               Yes
# 327 2021-12-01 13:34:00 2021-12-01 13:37:00  ...               Yes
# 328 2021-12-01 13:34:00 2021-12-01 13:37:00  ...               Yes
#
#     status_Dispensed status_TTOIn Title  TTOaddon Item Type  \
# 0               True         True   NaN       NaN      Item
# 1               True         True   NaN       NaN      Item
# 2               True         True   NaN       NaN      Item
# 3               True         True   NaN       NaN      Item
# 4              False         True   NaN       NaN      Item
# ..               ...          ...   ...       ...       ...
# 324              Yes          Yes   NaN       NaN       NaN
# 325              Yes          Yes   NaN       NaN       NaN
# 326              Yes          Yes   NaN       NaN       NaN
# 327              Yes          Yes   NaN       NaN       NaN
# 328              Yes           No   NaN       NaN       NaN
#
#                                                   Path Time Unnamed: 23  \
# 0    personal/rayhng_yeo_gleneagles_com_sg/Lists/TT...  NaN         NaN
# 1    personal/rayhng_yeo_gleneagles_com_sg/Lists/TT...  NaN         NaN
# 2    personal/rayhng_yeo_gleneagles_com_sg/Lists/TT...  NaN         NaN
# 3    personal/rayhng_yeo_gleneagles_com_sg/Lists/TT...  NaN         NaN
# 4    personal/rayhng_yeo_gleneagles_com_sg/Lists/TT...  NaN         NaN
# ..                                                 ...  ...         ...
# 324                                                NaN  NaN         NaN
# 325                                                NaN  NaN         NaN
# 326                                                NaN  NaN         NaN
# 327                                                NaN  NaN         NaN
# 328                                                NaN  NaN         NaN
#
#     Unnamed: 24
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 324         NaN
# 325         NaN
# 326         NaN
# 327         NaN
# 328         NaN
#
# [2589 rows x 28 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2589 entries, 0 to 328
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2312 non-null   datetime64[ns]
#  1   Case Number           2312 non-null   float64
#  2   Room                  2312 non-null   object
#  3   TTO Type              2303 non-null   object
#  4   No. of Items          2309 non-null   float64
#  5   Time In               2283 non-null   datetime64[ns]
#  6   Time Checked          2114 non-null   datetime64[ns]
#  7   Pharmacist_Checked    2105 non-null   object
#  8   Time Reached          1969 non-null   datetime64[ns]
#  9   Time Dispensed        1668 non-null   datetime64[ns]
#  10  Pharmacist_Dispensed  1831 non-null   object
#  11  Remarks               421 non-null    object
#  12  Dispatcher            1 non-null      object
#  13  TTO_TAT_Calc          2312 non-null   object
#  14  Total number of TTO   0 non-null      float64
#  15  Status_Time_Met       2312 non-null   object
#  16  ID                    2312 non-null   float64
#  17  status_CheckedTTO     2312 non-null   object
#  18  status_TTOReached     2312 non-null   object
#  19  status_Dispensed      2312 non-null   object
#  20  status_TTOIn          2312 non-null   object
#  21  Title                 0 non-null      float64
#  22  TTOaddon              0 non-null      float64
#  23  Item Type             717 non-null    object
#  24  Path                  717 non-null    object
#  25  Time                  1932 non-null   float64
#  26  Unnamed: 23           0 non-null      float64
#  27  Unnamed: 24           0 non-null      float64
# dtypes: datetime64[ns](5), float64(9), object(14)
# memory usage: 586.6+ KB

# %%
#reset index 
df3 = df3.reset_index(drop=True)

# %% [markdown]
# ### Drop columns

# %%
# drop columns that should be ignored
df3 = df3.drop(['TTO_TAT_Calc', 'Total number of TTO', 'Status_Time_Met', 'ID', 'Title', 'TTOaddon', 'Item Type', 'Path', 'Unnamed: 23', 'Unnamed: 24'], axis = 1)
# drop other redundant columns
#df3 = df3.drop(['Pharmacist_Checked', 'Pharmacist_Dispensed', 'Dispatcher' ], axis = 1)

# %% [markdown]
# ### Rename common columns

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589 entries, 0 to 2588
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2312 non-null   datetime64[ns]
#  1   Case Number           2312 non-null   float64
#  2   Room                  2312 non-null   object
#  3   TTO Type              2303 non-null   object
#  4   No. of Items          2309 non-null   float64
#  5   Time In               2283 non-null   datetime64[ns]
#  6   Time Checked          2114 non-null   datetime64[ns]
#  7   Pharmacist_Checked    2105 non-null   object
#  8   Time Reached          1969 non-null   datetime64[ns]
#  9   Time Dispensed        1668 non-null   datetime64[ns]
#  10  Pharmacist_Dispensed  1831 non-null   object
#  11  Remarks               421 non-null    object
#  12  Dispatcher            1 non-null      object
#  13  status_CheckedTTO     2312 non-null   object
#  14  status_TTOReached     2312 non-null   object
#  15  status_Dispensed      2312 non-null   object
#  16  status_TTOIn          2312 non-null   object
#  17  Time                  1932 non-null   float64
# dtypes: datetime64[ns](5), float64(3), object(10)
# memory usage: 364.2+ KB

# %%
df3.rename({'Room': 'Room Number',
            'No. of Items':'No. of Drugs', 
            'Time In': 'Time TTO Received', # the start time
            'Time Checked':'Time TTO Checked', 
            'Time Reached': 'Time TTO Reached', # the end time 
            'Time Dispensed' : 'Time TTO Counselled'},
           axis=1, inplace=True)

# %%
columns = ['Time TTO Received', 'Time TTO Checked', 'Time TTO Reached', 'Time TTO Counselled']

for column in columns:
    # remove date in the time metric
    #df3[column]=df3[column].dt.time 
    df3[column] = df3[column].astype(str).str.split(' ').str[-1]

# %%
df3
# Out:
#                     Date   Case Number Room Number TTO Type  No. of Drugs  \
# 0    2021-06-01 01:00:00  1.021039e+09         953      SCM           3.0
# 1    2021-06-01 01:00:00  1.021039e+09         623      SCM           1.0
# 2    2021-06-01 01:00:00  1.021039e+09         757      SCM           1.0
# 3    2021-06-01 01:00:00  1.021038e+09         916      SCM           4.0
# 4    2021-06-01 01:00:00  1.021039e+09         958      NaN           NaN
# ...                  ...           ...         ...      ...           ...
# 2584 2021-12-01 00:00:00  1.021086e+09         905      SCM           9.0
# 2585 2021-12-01 00:00:00  1.021087e+09         102      SCM           1.0
# 2586 2021-12-01 00:00:00  1.021085e+09         113      SCM           1.0
# 2587 2021-12-01 00:00:00  1.021085e+09         113      SCM           1.0
# 2588 2021-12-01 00:00:00  1.021085e+09         113      SCM           8.0
#
#      Time TTO Received Time TTO Checked       Pharmacist_Checked  \
# 0             09:13:00         09:07:17              Ray Hng Yeo
# 1             09:30:00         09:38:25              Ray Hng Yeo
# 2             09:36:00         09:43:48  Nur Shahida Binte Ahmad
# 3             09:46:00         09:49:54  Nur Shahida Binte Ahmad
# 4             08:55:00         09:56:00                 Wan Qing
# ...                ...              ...                      ...
# 2584          09:39:00         10:30:00              Hemin Chang
# 2585          11:30:00         11:42:00            Zhao Wan Qing
# 2586          12:26:00         12:38:00            Zhao Wan Qing
# 2587          13:11:00         13:17:00              Yi Zhen Tay
# 2588               NaT              NaT                      NaN
#
#      Time TTO Reached Time TTO Counselled Pharmacist_Dispensed  \
# 0            09:28:26            09:31:37        Zhao Wan Qing
# 1            10:07:32            10:09:24          Ray Hng Yeo
# 2            10:30:09            10:30:18          Ray Hng Yeo
# 3            10:12:22            10:13:34        Zhao Wan Qing
# 4            10:18:00                 NaT                  NaN
# ...               ...                 ...                  ...
# 2584         10:44:00            10:50:00          Hemin Chang
# 2585         12:08:00            12:12:00        Zhao Wan Qing
# 2586         12:45:00                 NaT        Zhao Wan Qing
# 2587         13:34:00            13:37:00          Hemin Chang
# 2588         13:34:00            13:37:00          Hemin Chang
#
#                     Remarks Dispatcher status_CheckedTTO status_TTOReached  \
# 0                       NaN        NaN              True              True
# 1                       NaN        NaN              True              True
# 2                       NaN        NaN              True              True
# 3                       NaN        NaN              True              True
# 4         9W remaining meds        NaN              True              True
# ...                     ...        ...               ...               ...
# 2584  ["9W remaining meds"]        NaN               Yes               Yes
# 2585                    NaN        NaN               Yes               Yes
# 2586                    NaN        NaN               Yes               Yes
# 2587                    NaN        NaN               Yes               Yes
# 2588                    NaN        NaN                No               Yes
#
#      status_Dispensed status_TTOIn  Time
# 0                True         True   NaN
# 1                True         True   NaN
# 2                True         True   NaN
# 3                True         True   NaN
# 4               False         True   NaN
# ...               ...          ...   ...
# 2584              Yes          Yes   NaN
# 2585              Yes          Yes   NaN
# 2586              Yes          Yes   NaN
# 2587              Yes          Yes   NaN
# 2588              Yes           No   NaN
#
# [2589 rows x 18 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589 entries, 0 to 2588
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2312 non-null   datetime64[ns]
#  1   Case Number           2312 non-null   float64
#  2   Room Number           2312 non-null   object
#  3   TTO Type              2303 non-null   object
#  4   No. of Drugs          2309 non-null   float64
#  5   Time TTO Received     2589 non-null   object
#  6   Time TTO Checked      2589 non-null   object
#  7   Pharmacist_Checked    2105 non-null   object
#  8   Time TTO Reached      2589 non-null   object
#  9   Time TTO Counselled   2589 non-null   object
#  10  Pharmacist_Dispensed  1831 non-null   object
#  11  Remarks               421 non-null    object
#  12  Dispatcher            1 non-null      object
#  13  status_CheckedTTO     2312 non-null   object
#  14  status_TTOReached     2312 non-null   object
#  15  status_Dispensed      2312 non-null   object
#  16  status_TTOIn          2312 non-null   object
#  17  Time                  1932 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(14)
# memory usage: 364.2+ KB

# %% [markdown]
# ### Handle missing value

# %%
df3.isnull().sum()
# Out:
# Date                     277
# Case Number              277
# Room Number              277
# TTO Type                 286
# No. of Drugs             280
# Time TTO Received          0
# Time TTO Checked           0
# Pharmacist_Checked       484
# Time TTO Reached           0
# Time TTO Counselled        0
# Pharmacist_Dispensed     758
# Remarks                 2168
# Dispatcher              2588
# status_CheckedTTO        277
# status_TTOReached        277
# status_Dispensed         277
# status_TTOIn             277
# Time                     657
# dtype: int64

# %% [markdown]
# #### Missing Date

# %%
# change to datetime format
df3['Date'] = pd.to_datetime(df3['Date'])

# %%
missing_date = df3[df3['Date'].isnull()]
missing_date
# Out:
#      Date  Case Number Room Number TTO Type  No. of Drugs Time TTO Received  \
# 1061  NaT          NaN         NaN      NaN           NaN               NaT
# 1062  NaT          NaN         NaN      NaN           NaN               NaT
# 1063  NaT          NaN         NaN      NaN           NaN               NaT
# 1064  NaT          NaN         NaN      NaN           NaN               NaT
# 1065  NaT          NaN         NaN      NaN           NaN               NaT
# ...   ...          ...         ...      ...           ...               ...
# 2255  NaT          NaN         NaN      NaN           NaN               NaT
# 2256  NaT          NaN         NaN      NaN           NaN               NaT
# 2257  NaT          NaN         NaN      NaN           NaN               NaT
# 2258  NaT          NaN         NaN      NaN           NaN               NaT
# 2259  NaT          NaN         NaN      NaN           NaN               NaT
#
#      Time TTO Checked Pharmacist_Checked Time TTO Reached Time TTO Counselled  \
# 1061              NaT                NaN              NaT                 NaT
# 1062              NaT                NaN              NaT                 NaT
# 1063              NaT                NaN              NaT                 NaT
# 1064              NaT                NaN              NaT                 NaT
# 1065              NaT                NaN              NaT                 NaT
# ...               ...                ...              ...                 ...
# 2255              NaT                NaN              NaT                 NaT
# 2256              NaT                NaN              NaT                 NaT
# 2257              NaT                NaN              NaT                 NaT
# 2258              NaT                NaN              NaT                 NaT
# 2259              NaT                NaN              NaT                 NaT
#
#      Pharmacist_Dispensed Remarks Dispatcher status_CheckedTTO  \
# 1061                  NaN     NaN        NaN               NaN
# 1062                  NaN     NaN        NaN               NaN
# 1063                  NaN     NaN        NaN               NaN
# 1064                  NaN     NaN        NaN               NaN
# 1065                  NaN     NaN        NaN               NaN
# ...                   ...     ...        ...               ...
# 2255                  NaN     NaN        NaN               NaN
# 2256                  NaN     NaN        NaN               NaN
# 2257                  NaN     NaN        NaN               NaN
# 2258                  NaN     NaN        NaN               NaN
# 2259                  NaN     NaN        NaN               NaN
#
#      status_TTOReached status_Dispensed status_TTOIn  Time
# 1061               NaN              NaN          NaN   0.0
# 1062               NaN              NaN          NaN   0.0
# 1063               NaN              NaN          NaN   0.0
# 1064               NaN              NaN          NaN   0.0
# 1065               NaN              NaN          NaN   0.0
# ...                ...              ...          ...   ...
# 2255               NaN              NaN          NaN   0.0
# 2256               NaN              NaN          NaN   0.0
# 2257               NaN              NaN          NaN   0.0
# 2258               NaN              NaN          NaN   0.0
# 2259               NaN              NaN          NaN   0.0
#
# [277 rows x 18 columns]

# %%
#drop rows
df3 = df3.dropna(subset=['Date'])

# %%
# missing pharmacist dispensed
missing_date = df3[df3['Pharmacist_Dispensed'].isnull()]
missing_date.head()
# Out:
#                   Date   Case Number Room Number     TTO Type  No. of Drugs  \
# 4  2021-06-01 01:00:00  1.021039e+09         958          NaN           NaN
# 6  2021-06-01 01:00:00  1.021040e+09         936          SCM           2.0
# 17 2021-06-02 01:00:00  1.021039e+09         948  Handwritten           2.0
# 18 2021-06-02 01:00:00  1.021024e+09         932          SCM           5.0
# 22 2021-06-02 01:00:00  1.021040e+09         963          SCM           2.0
#
#    Time TTO Received Time TTO Checked Pharmacist_Checked Time TTO Reached  \
# 4           08:55:00         09:56:00           Wan Qing         10:18:00
# 6           01:00:00         10:49:00                NaN         10:58:00
# 17          01:00:00         09:13:00                NaN         10:51:00
# 18          10:40:00         10:46:00        Ray Hng Yeo         10:55:00
# 22          10:43:00         11:02:00           Kwok Fai              NaT
#
#    Time TTO Counselled Pharmacist_Dispensed            Remarks Dispatcher  \
# 4                  NaT                  NaN  9W remaining meds        NaN
# 6                  NaT                  NaN       Passed to SN        NaN
# 17                 NaT                  NaN       Passed to SN        NaN
# 18                 NaT                  NaN       Passed to SN        NaN
# 22                 NaT                  NaN                NaN        NaN
#
#    status_CheckedTTO status_TTOReached status_Dispensed status_TTOIn  Time
# 4               True              True            False         True   NaN
# 6               True              True            False         True   NaN
# 17              True              True            False         True   NaN
# 18              True              True            False         True   NaN
# 22              True             False            False         True   NaN

# %%
df3['No. of Drugs'].replace(np.nan, 'NA', inplace = True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
missing_date = df3[df3['Time'].notnull()]
missing_date
# Out:
#            Date   Case Number Room Number TTO Type No. of Drugs  \
# 328  2021-07-01  1.021046e+09         226      SCM            5
# 329  2021-07-01  1.021047e+09         621      SCM            1
# 330  2021-07-01  1.021047e+09         622      SCM            5
# 331  2021-07-01  1.231045e+09         113      SCM            4
# 332  2021-07-01  1.021046e+09         507      SCM            2
# ...         ...           ...         ...      ...          ...
# 2202 2021-10-01  1.021069e+09         605      SCM            3
# 2203 2021-10-01  1.021071e+09         512      SCM            2
# 2204 2021-10-01  1.021070e+09         921      SCM            4
# 2205 2021-10-01  1.021072e+09         510      SCM            3
# 2206 2021-10-01  1.021072e+09         509      SCM            2
#
#      Time TTO Received Time TTO Checked Pharmacist_Checked Time TTO Reached  \
# 328           08:28:00              NaT                NaN              NaT
# 329           08:57:00         09:02:00        Yi Zhen Tay         09:40:00
# 330           09:14:00         09:29:00        Yi Zhen Tay         09:42:00
# 331           09:19:00         09:35:00    Yi Li Elise Yap         09:53:00
# 332           09:21:00         09:41:00    Yi Li Elise Yap         09:59:00
# ...                ...              ...                ...              ...
# 2202          14:25:00         14:48:00    Yi Li Elise Yap         15:06:00
# 2203          16:36:00         16:58:00    Yi Li Elise Yap         17:02:00
# 2204          16:47:00         16:54:00    Yi Li Elise Yap         17:07:00
# 2205          18:49:00         18:57:00         Choon Yuen         18:59:00
# 2206          18:00:00         18:06:00    Yi Li Elise Yap         19:06:00
#
#      Time TTO Counselled Pharmacist_Dispensed                    Remarks  \
# 328                  NaT                  NaN                        NaN
# 329             09:55:00          Yi Zhen Tay               Passed to SN
# 330             09:52:00          Yi Zhen Tay                        NaN
# 331             10:28:00          Samuel Lai       Patient not available
# 332                  NaT           Samuel Lai                        NaN
# ...                  ...                  ...                        ...
# 2202            15:09:00               Samuel                        NaN
# 2203                 NaT                Elise           ["Passed to SN"]
# 2204                 NaT                Elise           ["Passed to SN"]
# 2205            19:05:00      Yi Li Elise Yap                        NaN
# 2206            19:07:00      Yi Li Elise Yap  ["Patient not available"]
#
#      Dispatcher status_CheckedTTO status_TTOReached status_Dispensed  \
# 328         NaN             False             False            False
# 329         NaN              True              True             True
# 330         NaN              True              True             True
# 331         NaN              True              True             True
# 332         NaN              True              True             True
# ...         ...               ...               ...              ...
# 2202        NaN               Yes               Yes              Yes
# 2203        NaN               Yes               Yes               No
# 2204        NaN               Yes               Yes               No
# 2205        NaN               Yes               Yes              Yes
# 2206        NaN               Yes               Yes              Yes
#
#      status_TTOIn        Time
# 328          True  493.888889
# 329          True   41.805556
# 330          True   27.222222
# 331          True   33.055556
# 332          True   36.944444
# ...           ...         ...
# 2202          Yes   39.861111
# 2203          Yes   25.277778
# 2204          Yes   19.444444
# 2205          Yes    9.722222
# 2206          Yes   64.166667
#
# [1655 rows x 18 columns]

# %%
df3.isnull().sum()
# Out:
# Date                       0
# Case Number                0
# Room Number                0
# TTO Type                   9
# No. of Drugs               0
# Time TTO Received          0
# Time TTO Checked           0
# Pharmacist_Checked       207
# Time TTO Reached           0
# Time TTO Counselled        0
# Pharmacist_Dispensed     481
# Remarks                 1891
# Dispatcher              2311
# status_CheckedTTO          0
# status_TTOReached          0
# status_Dispensed           0
# status_TTOIn               0
# Time                     657
# dtype: int64

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Day of Week

# %%
# add weekday column
df3['Weekday'] = df3['Date'].dt.day_name()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Export to CSV for Final Merge

# %%
df3.to_csv("GEH TTO TAT (June-Dec 2021).csv", index = None, header=True)

# %% [markdown]
# ## Final Merge of the above CSVs

# %%
merged_df = pd.concat([df2, df3])

# %%
merged_df
# Out:
#            Date  Case Number Room Number Ward TTO Type No. of Drugs  \
# 0    2021-04-01   1021023186         957   9W      SCM            2
# 1    2021-04-01   1021023191         509   5E      SCM            3
# 2    2021-04-01   1021023190         508   5E      SCM            4
# 3    2021-04-01   1021023367         932   9E      SCM            2
# 4    2021-04-01   1021023455         909   9E      SCM            5
# ...         ...          ...         ...  ...      ...          ...
# 2584 2021-12-01  1.02109e+09         905  NaN      SCM            9
# 2585 2021-12-01  1.02109e+09         102  NaN      SCM            1
# 2586 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2587 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2588 2021-12-01  1.02108e+09         113  NaN      SCM            8
#
#      Time TTO Received Time TTO Checked Checked by Time to meet  ...  \
# 0             08:59:00         09:04:00        LET     09:44:00  ...
# 1             09:05:00         09:26:00        LET     09:50:00  ...
# 2             09:07:00         09:19:00        LET     09:52:00  ...
# 3             09:11:00         09:22:00      ELISE     09:56:00  ...
# 4             09:36:00         10:02:00      ELISE     10:21:00  ...
# ...                ...              ...        ...          ...  ...
# 2584          09:39:00         10:30:00        NaN          NaN  ...
# 2585          11:30:00         11:42:00        NaN          NaN  ...
# 2586          12:26:00         12:38:00        NaN          NaN  ...
# 2587          13:11:00         13:17:00        NaN          NaN  ...
# 2588               NaT              NaT        NaN          NaN  ...
#
#      Timings (Reached)    Weekday Pharmacist_Checked Pharmacist_Dispensed  \
# 0             00:30:00   Thursday                NaN                  NaN
# 1             00:24:00   Thursday                NaN                  NaN
# 2             00:25:00   Thursday                NaN                  NaN
# 3             00:26:00   Thursday                NaN                  NaN
# 4             00:45:00   Thursday                NaN                  NaN
# ...                ...        ...                ...                  ...
# 2584               NaN  Wednesday        Hemin Chang          Hemin Chang
# 2585               NaN  Wednesday      Zhao Wan Qing        Zhao Wan Qing
# 2586               NaN  Wednesday      Zhao Wan Qing        Zhao Wan Qing
# 2587               NaN  Wednesday        Yi Zhen Tay          Hemin Chang
# 2588               NaN  Wednesday                NaN          Hemin Chang
#
#      Dispatcher status_CheckedTTO status_TTOReached status_Dispensed  \
# 0           NaN               NaN               NaN              NaN
# 1           NaN               NaN               NaN              NaN
# 2           NaN               NaN               NaN              NaN
# 3           NaN               NaN               NaN              NaN
# 4           NaN               NaN               NaN              NaN
# ...         ...               ...               ...              ...
# 2584        NaN               Yes               Yes              Yes
# 2585        NaN               Yes               Yes              Yes
# 2586        NaN               Yes               Yes              Yes
# 2587        NaN               Yes               Yes              Yes
# 2588        NaN                No               Yes              Yes
#
#      status_TTOIn Time
# 0             NaN  NaN
# 1             NaN  NaN
# 2             NaN  NaN
# 3             NaN  NaN
# 4             NaN  NaN
# ...           ...  ...
# 2584          Yes  NaN
# 2585          Yes  NaN
# 2586          Yes  NaN
# 2587          Yes  NaN
# 2588           No  NaN
#
# [2803 rows x 26 columns]

# %%
merged_df['Date'] = pd.to_datetime(merged_df['Date']).dt.normalize()

# %%
merged_df.head()
# Out:
#         Date Case Number Room Number Ward TTO Type No. of Drugs  \
# 0 2021-04-01  1021023186         957   9W      SCM            2
# 1 2021-04-01  1021023191         509   5E      SCM            3
# 2 2021-04-01  1021023190         508   5E      SCM            4
# 3 2021-04-01  1021023367         932   9E      SCM            2
# 4 2021-04-01  1021023455         909   9E      SCM            5
#
#   Time TTO Received Time TTO Checked Checked by Time to meet  ...  \
# 0          08:59:00         09:04:00        LET     09:44:00  ...
# 1          09:05:00         09:26:00        LET     09:50:00  ...
# 2          09:07:00         09:19:00        LET     09:52:00  ...
# 3          09:11:00         09:22:00      ELISE     09:56:00  ...
# 4          09:36:00         10:02:00      ELISE     10:21:00  ...
#
#   Timings (Reached)   Weekday Pharmacist_Checked Pharmacist_Dispensed  \
# 0          00:30:00  Thursday                NaN                  NaN
# 1          00:24:00  Thursday                NaN                  NaN
# 2          00:25:00  Thursday                NaN                  NaN
# 3          00:26:00  Thursday                NaN                  NaN
# 4          00:45:00  Thursday                NaN                  NaN
#
#   Dispatcher status_CheckedTTO status_TTOReached status_Dispensed  \
# 0        NaN               NaN               NaN              NaN
# 1        NaN               NaN               NaN              NaN
# 2        NaN               NaN               NaN              NaN
# 3        NaN               NaN               NaN              NaN
# 4        NaN               NaN               NaN              NaN
#
#   status_TTOIn Time
# 0          NaN  NaN
# 1          NaN  NaN
# 2          NaN  NaN
# 3          NaN  NaN
# 4          NaN  NaN
#
# [5 rows x 26 columns]

# %%
list(merged_df.columns)
# Out:
# ['Date',
#  'Case Number',
#  'Room Number',
#  'Ward',
#  'TTO Type',
#  'No. of Drugs',
#  'Time TTO Received',
#  'Time TTO Checked',
#  'Checked by',
#  'Time to meet',
#  'Time TTO Reached',
#  'Time TTO Counselled',
#  'Counselled by',
#  'Remarks',
#  'Limo Service',
#  'Timings (Checked)',
#  'Timings (Reached)',
#  'Weekday',
#  'Pharmacist_Checked',
#  'Pharmacist_Dispensed',
#  'Dispatcher',
#  'status_CheckedTTO',
#  'status_TTOReached',
#  'status_Dispensed',
#  'status_TTOIn',
#  'Time']

# %%
merged_df = merged_df.drop(['Pharmacist_Checked','Pharmacist_Dispensed','Dispatcher','status_CheckedTTO','status_TTOReached','status_Dispensed','status_TTOIn','Time',
                           'Timings (Checked)','Timings (Reached)'],
                           axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2803 entries, 0 to 2588
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 2803 non-null   datetime64[ns]
#  1   Case Number          2803 non-null   object
#  2   Room Number          2803 non-null   object
#  3   Ward                 491 non-null    object
#  4   TTO Type             2794 non-null   object
#  5   No. of Drugs         2803 non-null   object
#  6   Time TTO Received    2803 non-null   object
#  7   Time TTO Checked     2779 non-null   object
#  8   Checked by           466 non-null    object
#  9   Time to meet         491 non-null    object
#  10  Time TTO Reached     2743 non-null   object
#  11  Time TTO Counselled  2699 non-null   object
#  12  Counselled by        420 non-null    object
#  13  Remarks              572 non-null    object
#  14  Limo Service         1 non-null      object
#  15  Weekday              2803 non-null   object
# dtypes: datetime64[ns](1), object(15)
# memory usage: 372.3+ KB

# %%
merged_df[merged_df.index.duplicated()]
# Out:
#           Date  Case Number Room Number Ward     TTO Type No. of Drugs  \
# 0   2021-06-01  1.02104e+09         953  NaN          SCM            3
# 1   2021-06-01  1.02104e+09         623  NaN          SCM            1
# 2   2021-06-01  1.02104e+09         757  NaN          SCM            1
# 3   2021-06-01  1.02104e+09         916  NaN          SCM            4
# 4   2021-06-01  1.02104e+09         958  NaN          NaN           NA
# ..         ...          ...         ...  ...          ...          ...
# 492 2021-07-14  1.02105e+09         916  NaN          SCM            2
# 493 2021-07-14  1.02105e+09         110  NaN  Handwritten            6
# 494 2021-07-14  1.02105e+09         226  NaN          SCM            1
# 495 2021-07-14  1.02105e+09         740  NaN  Handwritten            3
# 496 2021-07-14  1.02105e+09         762  NaN          SCM            1
#
#     Time TTO Received Time TTO Checked Checked by Time to meet  \
# 0            09:13:00         09:07:17        NaN          NaN
# 1            09:30:00         09:38:25        NaN          NaN
# 2            09:36:00         09:43:48        NaN          NaN
# 3            09:46:00         09:49:54        NaN          NaN
# 4            08:55:00         09:56:00        NaN          NaN
# ..                ...              ...        ...          ...
# 492          09:43:00              NaT        NaN          NaN
# 493          09:14:00         10:11:00        NaN          NaN
# 494          10:17:00              NaT        NaN          NaN
# 495          09:28:00         09:39:00        NaN          NaN
# 496          11:09:00         11:14:00        NaN          NaN
#
#     Time TTO Reached Time TTO Counselled Counselled by            Remarks  \
# 0           09:28:26            09:31:37           NaN                NaN
# 1           10:07:32            10:09:24           NaN                NaN
# 2           10:30:09            10:30:18           NaN                NaN
# 3           10:12:22            10:13:34           NaN                NaN
# 4           10:18:00                 NaT           NaN  9W remaining meds
# ..               ...                 ...           ...                ...
# 492              NaT                 NaT           NaN                NaN
# 493         12:35:00                 NaT           NaN                NaN
# 494              NaT                 NaT           NaN                NaN
# 495         10:44:00            10:50:00           NaN                NaN
# 496         11:42:00                 NaT           NaN                NaN
#
#     Limo Service    Weekday
# 0            NaN    Tuesday
# 1            NaN    Tuesday
# 2            NaN    Tuesday
# 3            NaN    Tuesday
# 4            NaN    Tuesday
# ..           ...        ...
# 492          NaN  Wednesday
# 493          NaN  Wednesday
# 494          NaN  Wednesday
# 495          NaN  Wednesday
# 496          NaN  Wednesday
#
# [491 rows x 16 columns]

# %%
#reset index 
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#            Date  Case Number Room Number Ward TTO Type No. of Drugs  \
# 0    2021-04-01   1021023186         957   9W      SCM            2
# 1    2021-04-01   1021023191         509   5E      SCM            3
# 2    2021-04-01   1021023190         508   5E      SCM            4
# 3    2021-04-01   1021023367         932   9E      SCM            2
# 4    2021-04-01   1021023455         909   9E      SCM            5
# ...         ...          ...         ...  ...      ...          ...
# 2798 2021-12-01  1.02109e+09         905  NaN      SCM            9
# 2799 2021-12-01  1.02109e+09         102  NaN      SCM            1
# 2800 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2801 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2802 2021-12-01  1.02108e+09         113  NaN      SCM            8
#
#      Time TTO Received Time TTO Checked Checked by Time to meet  \
# 0             08:59:00         09:04:00        LET     09:44:00
# 1             09:05:00         09:26:00        LET     09:50:00
# 2             09:07:00         09:19:00        LET     09:52:00
# 3             09:11:00         09:22:00      ELISE     09:56:00
# 4             09:36:00         10:02:00      ELISE     10:21:00
# ...                ...              ...        ...          ...
# 2798          09:39:00         10:30:00        NaN          NaN
# 2799          11:30:00         11:42:00        NaN          NaN
# 2800          12:26:00         12:38:00        NaN          NaN
# 2801          13:11:00         13:17:00        NaN          NaN
# 2802               NaT              NaT        NaN          NaN
#
#      Time TTO Reached Time TTO Counselled Counselled by  \
# 0            09:29:00            09:35:00           LET
# 1            09:29:00            09:32:00         ELISE
# 2            09:32:00            10:17:00         ELISE
# 3            09:37:00            09:40:00           LET
# 4            10:21:00            10:25:00         ELISE
# ...               ...                 ...           ...
# 2798         10:44:00            10:50:00           NaN
# 2799         12:08:00            12:12:00           NaN
# 2800         12:45:00                 NaT           NaN
# 2801         13:34:00            13:37:00           NaN
# 2802         13:34:00            13:37:00           NaN
#
#                     Remarks Limo Service    Weekday
# 0                       NaN          NaN   Thursday
# 1                       NaN          NaN   Thursday
# 2                         P          NaN   Thursday
# 3                       NaN          NaN   Thursday
# 4                       NaN          NaN   Thursday
# ...                     ...          ...        ...
# 2798  ["9W remaining meds"]          NaN  Wednesday
# 2799                    NaN          NaN  Wednesday
# 2800                    NaN          NaN  Wednesday
# 2801                    NaN          NaN  Wednesday
# 2802                    NaN          NaN  Wednesday
#
# [2803 rows x 16 columns]

# %% [markdown]
# #### Overall Time Taken (mins)

# %%
merged_df["Time TTO Reached"] = pd.to_datetime(merged_df[merged_df['Time TTO Reached'] != 'NA']['Time TTO Reached'].astype(str))
merged_df["Time TTO Counselled"]= pd.to_datetime(merged_df[merged_df['Time TTO Counselled'] != 'NA']['Time TTO Counselled'].astype(str))

# %%
merged_df["TTO Last Timestamp"] = merged_df[['Time TTO Reached', 'Time TTO Counselled']].max(axis=1)
#merged_df["Last Timestamp"]  = merged_df['Last Timestamp'].dt.time

# %%
#columns = ['Time TTO Reached', 'Time TTO Counselled', 'Last Timestamp']

#for column in column:
#    merged_df[column]  = merged_df[column].dt.time

# %%
#merged_df["Time TTO Received"]  = pd.to_datetime(merged_df["Time TTO Received"] , infer_datetime_format=True, errors='coerce')
#merged_df["Time TTO Reached"]  = pd.to_datetime(merged_df["Time TTO Reached"] , infer_datetime_format=True, errors='coerce')
#merged_df["Time TTO Counselled"]  = pd.to_datetime(merged_df["Time TTO Counselled"] , infer_datetime_format=True, errors='coerce')

# %%
merged_df["Time TTO Reached"]  = merged_df['Time TTO Reached'].dt.time
merged_df["Time TTO Counselled"]  = merged_df['Time TTO Counselled'].dt.time

# %%
merged_df["TTO Last Timestamp"]  = merged_df['TTO Last Timestamp'].dt.time

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2803 entries, 0 to 2802
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 2803 non-null   datetime64[ns]
#  1   Case Number          2803 non-null   object
#  2   Room Number          2803 non-null   object
#  3   Ward                 491 non-null    object
#  4   TTO Type             2794 non-null   object
#  5   No. of Drugs         2803 non-null   object
#  6   Time TTO Received    2803 non-null   object
#  7   Time TTO Checked     2779 non-null   object
#  8   Checked by           466 non-null    object
#  9   Time to meet         491 non-null    object
#  10  Time TTO Reached     2399 non-null   object
#  11  Time TTO Counselled  2055 non-null   object
#  12  Counselled by        420 non-null    object
#  13  Remarks              572 non-null    object
#  14  Limo Service         1 non-null      object
#  15  Weekday              2803 non-null   object
#  16  TTO Last Timestamp   2403 non-null   object
# dtypes: datetime64[ns](1), object(16)
# memory usage: 372.4+ KB

# %%
merged_df
# Out:
#            Date  Case Number Room Number Ward TTO Type No. of Drugs  \
# 0    2021-04-01   1021023186         957   9W      SCM            2
# 1    2021-04-01   1021023191         509   5E      SCM            3
# 2    2021-04-01   1021023190         508   5E      SCM            4
# 3    2021-04-01   1021023367         932   9E      SCM            2
# 4    2021-04-01   1021023455         909   9E      SCM            5
# ...         ...          ...         ...  ...      ...          ...
# 2798 2021-12-01  1.02109e+09         905  NaN      SCM            9
# 2799 2021-12-01  1.02109e+09         102  NaN      SCM            1
# 2800 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2801 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2802 2021-12-01  1.02108e+09         113  NaN      SCM            8
#
#      Time TTO Received Time TTO Checked Checked by Time to meet  \
# 0             08:59:00         09:04:00        LET     09:44:00
# 1             09:05:00         09:26:00        LET     09:50:00
# 2             09:07:00         09:19:00        LET     09:52:00
# 3             09:11:00         09:22:00      ELISE     09:56:00
# 4             09:36:00         10:02:00      ELISE     10:21:00
# ...                ...              ...        ...          ...
# 2798          09:39:00         10:30:00        NaN          NaN
# 2799          11:30:00         11:42:00        NaN          NaN
# 2800          12:26:00         12:38:00        NaN          NaN
# 2801          13:11:00         13:17:00        NaN          NaN
# 2802               NaT              NaT        NaN          NaN
#
#      Time TTO Reached Time TTO Counselled Counselled by  \
# 0            09:29:00            09:35:00           LET
# 1            09:29:00            09:32:00         ELISE
# 2            09:32:00            10:17:00         ELISE
# 3            09:37:00            09:40:00           LET
# 4            10:21:00            10:25:00         ELISE
# ...               ...                 ...           ...
# 2798         10:44:00            10:50:00           NaN
# 2799         12:08:00            12:12:00           NaN
# 2800         12:45:00                 NaT           NaN
# 2801         13:34:00            13:37:00           NaN
# 2802         13:34:00            13:37:00           NaN
#
#                     Remarks Limo Service    Weekday TTO Last Timestamp
# 0                       NaN          NaN   Thursday           09:35:00
# 1                       NaN          NaN   Thursday           09:32:00
# 2                         P          NaN   Thursday           10:17:00
# 3                       NaN          NaN   Thursday           09:40:00
# 4                       NaN          NaN   Thursday           10:25:00
# ...                     ...          ...        ...                ...
# 2798  ["9W remaining meds"]          NaN  Wednesday           10:50:00
# 2799                    NaN          NaN  Wednesday           12:12:00
# 2800                    NaN          NaN  Wednesday           12:45:00
# 2801                    NaN          NaN  Wednesday           13:37:00
# 2802                    NaN          NaN  Wednesday           13:37:00
#
# [2803 rows x 17 columns]

# %%
tto_received = pd.to_datetime(merged_df['Time TTO Received'].astype(str)) 
tto_last_pt = pd.to_datetime(merged_df[merged_df['TTO Last Timestamp'] != 'NA']['TTO Last Timestamp'].astype(str))
#tto_counselled = pd.to_datetime(df2[df2['Time TTO Counselled'] != 'NA']['Time TTO Counselled'].astype(str))

merged_df['Overall Time Taken (mins)'] = tto_last_pt.sub(tto_received).dt.total_seconds().div(60)

# %%
merged_df
# Out:
#            Date  Case Number Room Number Ward TTO Type No. of Drugs  \
# 0    2021-04-01   1021023186         957   9W      SCM            2
# 1    2021-04-01   1021023191         509   5E      SCM            3
# 2    2021-04-01   1021023190         508   5E      SCM            4
# 3    2021-04-01   1021023367         932   9E      SCM            2
# 4    2021-04-01   1021023455         909   9E      SCM            5
# ...         ...          ...         ...  ...      ...          ...
# 2798 2021-12-01  1.02109e+09         905  NaN      SCM            9
# 2799 2021-12-01  1.02109e+09         102  NaN      SCM            1
# 2800 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2801 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2802 2021-12-01  1.02108e+09         113  NaN      SCM            8
#
#      Time TTO Received Time TTO Checked Checked by Time to meet  \
# 0             08:59:00         09:04:00        LET     09:44:00
# 1             09:05:00         09:26:00        LET     09:50:00
# 2             09:07:00         09:19:00        LET     09:52:00
# 3             09:11:00         09:22:00      ELISE     09:56:00
# 4             09:36:00         10:02:00      ELISE     10:21:00
# ...                ...              ...        ...          ...
# 2798          09:39:00         10:30:00        NaN          NaN
# 2799          11:30:00         11:42:00        NaN          NaN
# 2800          12:26:00         12:38:00        NaN          NaN
# 2801          13:11:00         13:17:00        NaN          NaN
# 2802               NaT              NaT        NaN          NaN
#
#      Time TTO Reached Time TTO Counselled Counselled by  \
# 0            09:29:00            09:35:00           LET
# 1            09:29:00            09:32:00         ELISE
# 2            09:32:00            10:17:00         ELISE
# 3            09:37:00            09:40:00           LET
# 4            10:21:00            10:25:00         ELISE
# ...               ...                 ...           ...
# 2798         10:44:00            10:50:00           NaN
# 2799         12:08:00            12:12:00           NaN
# 2800         12:45:00                 NaT           NaN
# 2801         13:34:00            13:37:00           NaN
# 2802         13:34:00            13:37:00           NaN
#
#                     Remarks Limo Service    Weekday TTO Last Timestamp  \
# 0                       NaN          NaN   Thursday           09:35:00
# 1                       NaN          NaN   Thursday           09:32:00
# 2                         P          NaN   Thursday           10:17:00
# 3                       NaN          NaN   Thursday           09:40:00
# 4                       NaN          NaN   Thursday           10:25:00
# ...                     ...          ...        ...                ...
# 2798  ["9W remaining meds"]          NaN  Wednesday           10:50:00
# 2799                    NaN          NaN  Wednesday           12:12:00
# 2800                    NaN          NaN  Wednesday           12:45:00
# 2801                    NaN          NaN  Wednesday           13:37:00
# 2802                    NaN          NaN  Wednesday           13:37:00
#
#       Overall Time Taken (mins)
# 0                          36.0
# 1                          27.0
# 2                          70.0
# 3                          29.0
# 4                          49.0
# ...                         ...
# 2798                       71.0
# 2799                       42.0
# 2800                       19.0
# 2801                       26.0
# 2802                        NaN
#
# [2803 rows x 18 columns]

# %% [markdown]
# #### Meet KPI

# %%
def f(row):
    if row['Overall Time Taken (mins)'] > 45:
        val = 'No'
    elif row['Overall Time Taken (mins)'] > 0 and row['Overall Time Taken (mins)'] <= 45:
        val = 'Yes'
    else:
        val = 'NA'
    return val

# %%
merged_df['Meet KPI'] = merged_df.apply(f, axis=1)
merged_df
# Out:
#            Date  Case Number Room Number Ward TTO Type No. of Drugs  \
# 0    2021-04-01   1021023186         957   9W      SCM            2
# 1    2021-04-01   1021023191         509   5E      SCM            3
# 2    2021-04-01   1021023190         508   5E      SCM            4
# 3    2021-04-01   1021023367         932   9E      SCM            2
# 4    2021-04-01   1021023455         909   9E      SCM            5
# ...         ...          ...         ...  ...      ...          ...
# 2798 2021-12-01  1.02109e+09         905  NaN      SCM            9
# 2799 2021-12-01  1.02109e+09         102  NaN      SCM            1
# 2800 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2801 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2802 2021-12-01  1.02108e+09         113  NaN      SCM            8
#
#      Time TTO Received Time TTO Checked Checked by Time to meet  \
# 0             08:59:00         09:04:00        LET     09:44:00
# 1             09:05:00         09:26:00        LET     09:50:00
# 2             09:07:00         09:19:00        LET     09:52:00
# 3             09:11:00         09:22:00      ELISE     09:56:00
# 4             09:36:00         10:02:00      ELISE     10:21:00
# ...                ...              ...        ...          ...
# 2798          09:39:00         10:30:00        NaN          NaN
# 2799          11:30:00         11:42:00        NaN          NaN
# 2800          12:26:00         12:38:00        NaN          NaN
# 2801          13:11:00         13:17:00        NaN          NaN
# 2802               NaT              NaT        NaN          NaN
#
#      Time TTO Reached Time TTO Counselled Counselled by  \
# 0            09:29:00            09:35:00           LET
# 1            09:29:00            09:32:00         ELISE
# 2            09:32:00            10:17:00         ELISE
# 3            09:37:00            09:40:00           LET
# 4            10:21:00            10:25:00         ELISE
# ...               ...                 ...           ...
# 2798         10:44:00            10:50:00           NaN
# 2799         12:08:00            12:12:00           NaN
# 2800         12:45:00                 NaT           NaN
# 2801         13:34:00            13:37:00           NaN
# 2802         13:34:00            13:37:00           NaN
#
#                     Remarks Limo Service    Weekday TTO Last Timestamp  \
# 0                       NaN          NaN   Thursday           09:35:00
# 1                       NaN          NaN   Thursday           09:32:00
# 2                         P          NaN   Thursday           10:17:00
# 3                       NaN          NaN   Thursday           09:40:00
# 4                       NaN          NaN   Thursday           10:25:00
# ...                     ...          ...        ...                ...
# 2798  ["9W remaining meds"]          NaN  Wednesday           10:50:00
# 2799                    NaN          NaN  Wednesday           12:12:00
# 2800                    NaN          NaN  Wednesday           12:45:00
# 2801                    NaN          NaN  Wednesday           13:37:00
# 2802                    NaN          NaN  Wednesday           13:37:00
#
#       Overall Time Taken (mins) Meet KPI
# 0                          36.0      Yes
# 1                          27.0      Yes
# 2                          70.0       No
# 3                          29.0      Yes
# 4                          49.0       No
# ...                         ...      ...
# 2798                       71.0       No
# 2799                       42.0      Yes
# 2800                       19.0      Yes
# 2801                       26.0      Yes
# 2802                        NaN       NA
#
# [2803 rows x 19 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2803 entries, 0 to 2802
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2803 non-null   datetime64[ns]
#  1   Case Number                2803 non-null   object
#  2   Room Number                2803 non-null   object
#  3   Ward                       491 non-null    object
#  4   TTO Type                   2794 non-null   object
#  5   No. of Drugs               2803 non-null   object
#  6   Time TTO Received          2803 non-null   object
#  7   Time TTO Checked           2779 non-null   object
#  8   Checked by                 466 non-null    object
#  9   Time to meet               491 non-null    object
#  10  Time TTO Reached           2399 non-null   object
#  11  Time TTO Counselled        2055 non-null   object
#  12  Counselled by              420 non-null    object
#  13  Remarks                    572 non-null    object
#  14  Limo Service               1 non-null      object
#  15  Weekday                    2803 non-null   object
#  16  TTO Last Timestamp         2403 non-null   object
#  17  Overall Time Taken (mins)  2396 non-null   float64
#  18  Meet KPI                   2803 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(17)
# memory usage: 416.2+ KB

# %% [markdown]
# #### Office Hour

# %%
x = datetime.strptime('08:30:00', '%H:%M:%S').time()
x
# Out:
# datetime.time(8, 30)

# %%
merged_df["Time TTO Received"]  = pd.to_datetime(merged_df["Time TTO Received"].astype(str))
merged_df["TTO Last Timestamp"]  = pd.to_datetime(merged_df["TTO Last Timestamp"].astype(str))
#merged_df["TTO Last Timestamp"]  = pd.to_datetime(merged_df["TTO Last Timestamp"] , infer_datetime_format=True, errors='coerce')

# %%
merged_df
# Out:
#            Date  Case Number Room Number Ward TTO Type No. of Drugs  \
# 0    2021-04-01   1021023186         957   9W      SCM            2
# 1    2021-04-01   1021023191         509   5E      SCM            3
# 2    2021-04-01   1021023190         508   5E      SCM            4
# 3    2021-04-01   1021023367         932   9E      SCM            2
# 4    2021-04-01   1021023455         909   9E      SCM            5
# ...         ...          ...         ...  ...      ...          ...
# 2798 2021-12-01  1.02109e+09         905  NaN      SCM            9
# 2799 2021-12-01  1.02109e+09         102  NaN      SCM            1
# 2800 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2801 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2802 2021-12-01  1.02108e+09         113  NaN      SCM            8
#
#        Time TTO Received Time TTO Checked Checked by Time to meet  \
# 0    2022-03-03 08:59:00         09:04:00        LET     09:44:00
# 1    2022-03-03 09:05:00         09:26:00        LET     09:50:00
# 2    2022-03-03 09:07:00         09:19:00        LET     09:52:00
# 3    2022-03-03 09:11:00         09:22:00      ELISE     09:56:00
# 4    2022-03-03 09:36:00         10:02:00      ELISE     10:21:00
# ...                  ...              ...        ...          ...
# 2798 2022-03-03 09:39:00         10:30:00        NaN          NaN
# 2799 2022-03-03 11:30:00         11:42:00        NaN          NaN
# 2800 2022-03-03 12:26:00         12:38:00        NaN          NaN
# 2801 2022-03-03 13:11:00         13:17:00        NaN          NaN
# 2802                 NaT              NaT        NaN          NaN
#
#      Time TTO Reached Time TTO Counselled Counselled by  \
# 0            09:29:00            09:35:00           LET
# 1            09:29:00            09:32:00         ELISE
# 2            09:32:00            10:17:00         ELISE
# 3            09:37:00            09:40:00           LET
# 4            10:21:00            10:25:00         ELISE
# ...               ...                 ...           ...
# 2798         10:44:00            10:50:00           NaN
# 2799         12:08:00            12:12:00           NaN
# 2800         12:45:00                 NaT           NaN
# 2801         13:34:00            13:37:00           NaN
# 2802         13:34:00            13:37:00           NaN
#
#                     Remarks Limo Service    Weekday  TTO Last Timestamp  \
# 0                       NaN          NaN   Thursday 2022-03-03 09:35:00
# 1                       NaN          NaN   Thursday 2022-03-03 09:32:00
# 2                         P          NaN   Thursday 2022-03-03 10:17:00
# 3                       NaN          NaN   Thursday 2022-03-03 09:40:00
# 4                       NaN          NaN   Thursday 2022-03-03 10:25:00
# ...                     ...          ...        ...                 ...
# 2798  ["9W remaining meds"]          NaN  Wednesday 2022-03-03 10:50:00
# 2799                    NaN          NaN  Wednesday 2022-03-03 12:12:00
# 2800                    NaN          NaN  Wednesday 2022-03-03 12:45:00
# 2801                    NaN          NaN  Wednesday 2022-03-03 13:37:00
# 2802                    NaN          NaN  Wednesday 2022-03-03 13:37:00
#
#       Overall Time Taken (mins) Meet KPI
# 0                          36.0      Yes
# 1                          27.0      Yes
# 2                          70.0       No
# 3                          29.0      Yes
# 4                          49.0       No
# ...                         ...      ...
# 2798                       71.0       No
# 2799                       42.0      Yes
# 2800                       19.0      Yes
# 2801                       26.0      Yes
# 2802                        NaN       NA
#
# [2803 rows x 19 columns]

# %%
merged_df["Time TTO Received"]   = merged_df["Time TTO Received"].dt.time
merged_df["TTO Last Timestamp"]   = merged_df["TTO Last Timestamp"].dt.time

# %%
merged_df['Office Hours'] = np.where(merged_df['Time TTO Received'].isnull() | merged_df['TTO Last Timestamp'].isnull() , 'NA',
                            np.where(  ((merged_df['Time TTO Received'] >= pd.to_datetime('08:30:00').time()  ) & 
                                        (merged_df['TTO Last Timestamp'] <= pd.to_datetime('17:00:00').time())),
                                        'Yes', 'No'))

merged_df
# Out:
#            Date  Case Number Room Number Ward TTO Type No. of Drugs  \
# 0    2021-04-01   1021023186         957   9W      SCM            2
# 1    2021-04-01   1021023191         509   5E      SCM            3
# 2    2021-04-01   1021023190         508   5E      SCM            4
# 3    2021-04-01   1021023367         932   9E      SCM            2
# 4    2021-04-01   1021023455         909   9E      SCM            5
# ...         ...          ...         ...  ...      ...          ...
# 2798 2021-12-01  1.02109e+09         905  NaN      SCM            9
# 2799 2021-12-01  1.02109e+09         102  NaN      SCM            1
# 2800 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2801 2021-12-01  1.02108e+09         113  NaN      SCM            1
# 2802 2021-12-01  1.02108e+09         113  NaN      SCM            8
#
#      Time TTO Received Time TTO Checked Checked by Time to meet  \
# 0             08:59:00         09:04:00        LET     09:44:00
# 1             09:05:00         09:26:00        LET     09:50:00
# 2             09:07:00         09:19:00        LET     09:52:00
# 3             09:11:00         09:22:00      ELISE     09:56:00
# 4             09:36:00         10:02:00      ELISE     10:21:00
# ...                ...              ...        ...          ...
# 2798          09:39:00         10:30:00        NaN          NaN
# 2799          11:30:00         11:42:00        NaN          NaN
# 2800          12:26:00         12:38:00        NaN          NaN
# 2801          13:11:00         13:17:00        NaN          NaN
# 2802               NaT              NaT        NaN          NaN
#
#      Time TTO Reached Time TTO Counselled Counselled by  \
# 0            09:29:00            09:35:00           LET
# 1            09:29:00            09:32:00         ELISE
# 2            09:32:00            10:17:00         ELISE
# 3            09:37:00            09:40:00           LET
# 4            10:21:00            10:25:00         ELISE
# ...               ...                 ...           ...
# 2798         10:44:00            10:50:00           NaN
# 2799         12:08:00            12:12:00           NaN
# 2800         12:45:00                 NaT           NaN
# 2801         13:34:00            13:37:00           NaN
# 2802         13:34:00            13:37:00           NaN
#
#                     Remarks Limo Service    Weekday TTO Last Timestamp  \
# 0                       NaN          NaN   Thursday           09:35:00
# 1                       NaN          NaN   Thursday           09:32:00
# 2                         P          NaN   Thursday           10:17:00
# 3                       NaN          NaN   Thursday           09:40:00
# 4                       NaN          NaN   Thursday           10:25:00
# ...                     ...          ...        ...                ...
# 2798  ["9W remaining meds"]          NaN  Wednesday           10:50:00
# 2799                    NaN          NaN  Wednesday           12:12:00
# 2800                    NaN          NaN  Wednesday           12:45:00
# 2801                    NaN          NaN  Wednesday           13:37:00
# 2802                    NaN          NaN  Wednesday           13:37:00
#
#       Overall Time Taken (mins) Meet KPI Office Hours
# 0                          36.0      Yes          Yes
# 1                          27.0      Yes          Yes
# 2                          70.0       No          Yes
# 3                          29.0      Yes          Yes
# 4                          49.0       No          Yes
# ...                         ...      ...          ...
# 2798                       71.0       No          Yes
# 2799                       42.0      Yes          Yes
# 2800                       19.0      Yes          Yes
# 2801                       26.0      Yes          Yes
# 2802                        NaN       NA           NA
#
# [2803 rows x 20 columns]

# %% [markdown]
# ### Export Final CLEANED to csv

# %%
merged_df.to_csv("GEH TTO TAT (cleaned).csv", index = None, header=True)

# %%
merged_df.isnull().sum()
# Out:
# Date                            0
# Case Number                     0
# Room Number                     0
# Ward                         2312
# TTO Type                        9
# No. of Drugs                    0
# Time TTO Received              29
# Time TTO Checked               24
# Checked by                   2337
# Time to meet                 2312
# Time TTO Reached              404
# Time TTO Counselled           748
# Counselled by                2383
# Remarks                      2231
# Limo Service                 2802
# Weekday                         0
# TTO Last Timestamp            400
# Overall Time Taken (mins)     407
# Meet KPI                        0
# Office Hours                    0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv("GEH TTO TAT (cleaned).csv")

# %%
df.notnull().sum()
# Out:
# Date                         2803
# Case Number                  2803
# Room Number                  2803
# Ward                          491
# TTO Type                     2794
# No. of Drugs                 2800
# Time TTO Received            2774
# Time TTO Checked             2779
# Checked by                    466
# Time to meet                  491
# Time TTO Reached             2399
# Time TTO Counselled          2055
# Counselled by                 420
# Remarks                       572
# Limo Service                    1
# Weekday                      2803
# TTO Last Timestamp           2403
# Overall Time Taken (mins)    2396
# Meet KPI                     2365
# Office Hours                 2396
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                            0
# Case Number                     0
# Room Number                     0
# Ward                         2312
# TTO Type                        9
# No. of Drugs                    3
# Time TTO Received              29
# Time TTO Checked               24
# Checked by                   2337
# Time to meet                 2312
# Time TTO Reached              404
# Time TTO Counselled           748
# Counselled by                2383
# Remarks                      2231
# Limo Service                 2802
# Weekday                         0
# TTO Last Timestamp            400
# Overall Time Taken (mins)     407
# Meet KPI                      438
# Office Hours                  407
# dtype: int64

# %% [markdown]
# ### Average Prescriptions Filled Per Month

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.groupby(df['Date'].dt.strftime('%B'))['No. of Drugs'].sum().sort_values()

# %%
df.groupby(df['Date'].dt.strftime('%B'))['No. of Items'].mean().sort_values()
