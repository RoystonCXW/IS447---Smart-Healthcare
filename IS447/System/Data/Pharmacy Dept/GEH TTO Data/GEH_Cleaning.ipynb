# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
path = os.getcwd()
files = os.listdir(path)
files
# Out:
# ['.ipynb_checkpoints',
#  'GEH TTO TAT (April 2021).xlsx',
#  'GEH TTO TAT (April-May 2021).csv',
#  'GEH TTO TAT (FEB 2021).xlsx',
#  'GEH TTO TAT (JAN 2021).xlsx',
#  'GEH TTO TAT (June-Dec 2021).csv',
#  'GEH TTO TAT (Mar 2021) .xlsx',
#  'GEH TTO TAT 2021 Aug.xlsx',
#  'GEH TTO TAT 2021 Dec.xlsx',
#  'GEH TTO TAT 2021 July.xlsx',
#  'GEH TTO TAT 2021 June.xlsx',
#  'GEH TTO TAT 2021 May.xlsx',
#  'GEH TTO TAT 2021 Nov.xlsx',
#  'GEH TTO TAT 2021 Oct.xlsx',
#  'GEH TTO TAT 2021 Sep.xlsx',
#  'GEH_Cleaning.ipynb',
#  '~$GEH TTO TAT 2021 Aug.xlsx',
#  '~$GEH TTO TAT 2021 Dec.xlsx',
#  '~$GEH TTO TAT 2021 July.xlsx',
#  '~$GEH TTO TAT 2021 June.xlsx',
#  '~$GEH TTO TAT 2021 Nov.xlsx',
#  '~$GEH TTO TAT 2021 Oct.xlsx',
#  '~$GEH TTO TAT 2021 Sep.xlsx']

# %%
#files_xls = [f for f in files if f[-4:] == 'xlsx']

# %% [markdown]
# # Merge April & May Data

# %%
files_xls_1 = ['GEH TTO TAT (April 2021).xlsx','GEH TTO TAT 2021 May.xlsx']

# %%
df = pd.DataFrame()

# %%
for f in files_xls_1:
    data = pd.read_excel(f, 'Template')
    df = df.append(data)

# %%
df
# Out:
#              Verifier/Typist  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                      Date      Case No    Room No       Ward
# 1        2021-04-01 00:00:00  1021023186        957         9W
# 2        2021-04-01 00:00:00  1021023191        509         5E
# 3        2021-04-01 00:00:00  1021023190        508         5E
# 4        2021-04-01 00:00:00  1021023367        932         9E
# ...                      ...         ...        ...        ...
# 1048570                  NaN         NaN        NaN        NaN
# 1048571                  NaN         NaN        NaN        NaN
# 1048572                  NaN         NaN        NaN        NaN
# 1048573                  NaN         NaN        NaN        NaN
# 1048574                  NaN         NaN        NaN        NaN
#
#                      Unnamed: 4    Unnamed: 5          Unnamed: 6  \
# 0        SCM / Handwritten TTO   No. of items  Time in / Verified
# 1                           SCM             2            08:59:00
# ...

# %%
# Read and store content
# of an excel file 
#read_file = pd.read_excel("GEH TTO TAT (April 2021).xlsx", "Template")
  
# Write the dataframe object
# into csv file
#read_file.to_csv ("GEH TTO TAT (April 2021).csv", 
#                  index = None,
#                  header=True)

#df = pd.DataFrame(pd.read_csv("GEH TTO TAT (April 2021).csv"))

# %%
df.columns = df.iloc[0]

# %%
df = df.drop(0)
df
# Out:
# 0                      Date      Case No Room No Ward SCM / Handwritten TTO   \
# 1        2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 2        2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 3        2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 4        2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 5        2021-04-01 00:00:00  1021023455     909   9E                    SCM
# ...                      ...         ...     ...  ...                    ...
# 1048570                  NaN         NaN     NaN  NaN                    NaN
# 1048571                  NaN         NaN     NaN  NaN                    NaN
# 1048572                  NaN         NaN     NaN  NaN                    NaN
# 1048573                  NaN         NaN     NaN  NaN                    NaN
# 1048574                  NaN         NaN     NaN  NaN                    NaN
#
# ...

# %%
df = df.dropna(axis=1, how='all')
df
# Out:
# 0                      Date      Case No Room No Ward SCM / Handwritten TTO   \
# 1        2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 2        2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 3        2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 4        2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 5        2021-04-01 00:00:00  1021023455     909   9E                    SCM
# ...                      ...         ...     ...  ...                    ...
# 1048570                  NaN         NaN     NaN  NaN                    NaN
# 1048571                  NaN         NaN     NaN  NaN                    NaN
# 1048572                  NaN         NaN     NaN  NaN                    NaN
# 1048573                  NaN         NaN     NaN  NaN                    NaN
# 1048574                  NaN         NaN     NaN  NaN                    NaN
#
# ...

# %%
df = df[pd.notnull(df['Case No'])]

# %%
df
# Out:
# 0                  Date      Case No Room No Ward SCM / Handwritten TTO   \
# 1    2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 2    2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 3    2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 4    2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 5    2021-04-01 00:00:00  1021023455     909   9E                    SCM
# ..                   ...         ...     ...  ...                    ...
# 203                  NaN  1021037723     112  10W                    SCM
# 204                  NaN  1021037197     921   9E                    SCM
# 205                  NaN  1021037427     101  10W                    SCM
# 206                  NaN  1021039189     928   9E                    scm
# 207                  NaN  1021038490     622   TU                    SCM
#
# 0   No. of items Time in / Verified Time checked Checked by Time to meet  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497 entries, 1 to 207
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    423 non-null    object
#  1   Case No                 497 non-null    object
#  2   Room No                 497 non-null    object
#  3   Ward                    497 non-null    object
#  4   SCM / Handwritten TTO   497 non-null    object
#  5   No. of items            497 non-null    object
#  6   Time in / Verified      491 non-null    object
#  7   Time checked            471 non-null    object
#  8   Checked by              471 non-null    object
#  9   Time to meet            497 non-null    object
#  10  Time reached            434 non-null    object
#  11   Time Counselled        390 non-null    object
#  12  Counselled by           423 non-null    object
#  13  Remarks                 154 non-null    object
# ...

# %%
df.isnull()
# Out:
# 0    Date   Case No  Room No   Ward  SCM / Handwritten TTO   No. of items  \
# 1    False    False    False  False                   False         False
# 2    False    False    False  False                   False         False
# 3    False    False    False  False                   False         False
# 4    False    False    False  False                   False         False
# 5    False    False    False  False                   False         False
# ..     ...      ...      ...    ...                     ...           ...
# 203   True    False    False  False                   False         False
# 204   True    False    False  False                   False         False
# 205   True    False    False  False                   False         False
# 206   True    False    False  False                   False         False
# 207   True    False    False  False                   False         False
#
# 0    Time in / Verified  Time checked  Checked by  Time to meet  \
# ...

# %%
df.isnull().count()
# Out:
# 0
# Date                      497
# Case No                   497
# Room No                   497
# Ward                      497
# SCM / Handwritten TTO     497
# No. of items              497
# Time in / Verified        497
# Time checked              497
# Checked by                497
# Time to meet              497
# Time reached              497
#  Time Counselled          497
# Counselled by             497
# Remarks                   497
# Limo Service              497
# Timings (Checked)         497
# Timings (Reached)         497
# NaN                       497
# dtype: int64

# %%
df.notnull().count()
# Out:
# 0
# Date                      497
# Case No                   497
# Room No                   497
# Ward                      497
# SCM / Handwritten TTO     497
# No. of items              497
# Time in / Verified        497
# Time checked              497
# Checked by                497
# Time to meet              497
# Time reached              497
#  Time Counselled          497
# Counselled by             497
# Remarks                   497
# Limo Service              497
# Timings (Checked)         497
# Timings (Reached)         497
# NaN                       497
# dtype: int64

# %%
df.describe()
# Out:
# 0                     Date      Case No  Room No Ward SCM / Handwritten TTO   \
# count                   423         497      497  497                    497
# unique                   45         443      131   15                      4
# top     2021-04-21 00:00:00  1021023078      736   9W                    SCM
# freq                     25           4       14  105                    436
#
# 0       No. of items Time in / Verified Time checked Checked by Time to meet  \
# count            497                491          471        471          497
# unique            15                208          215         21          208
# top                1           08:40:00     09:22:00      ELISE     10:15:00
# freq             131                 11            9        116           11
#
# 0      Time reached   Time Counselled Counselled by       Remarks  \
# count            434              390           423           154
# ...

# %%
df.to_csv("GEH TTO TAT (April-May 2021).csv", index = None, header=True)

# %% [markdown]
# # Merge remaining months

# %%
files_xls_2 = ['GEH TTO TAT 2021 June.xlsx',
 'GEH TTO TAT 2021 July.xlsx',
 'GEH TTO TAT 2021 Aug.xlsx',
'GEH TTO TAT 2021 Sep.xlsx',
 'GEH TTO TAT 2021 Nov.xlsx', 'GEH TTO TAT 2021 Oct.xlsx', 
 'GEH TTO TAT 2021 Dec.xlsx']

# %%
df2 = pd.DataFrame()
for f in files_xls_2:
    data = pd.read_excel(f)
    df2 = df2.append(data)
df2
# Out:
#                    Date   Case Number Room TTO Type  No. of Items  \
# 0   2021-06-01 01:00:00  1.021039e+09  953      SCM           3.0
# 1   2021-06-01 01:00:00  1.021039e+09  623      SCM           1.0
# 2   2021-06-01 01:00:00  1.021039e+09  757      SCM           1.0
# 3   2021-06-01 01:00:00  1.021038e+09  916      SCM           4.0
# 4   2021-06-01 01:00:00  1.021039e+09  958      NaN           NaN
# ..                  ...           ...  ...      ...           ...
# 324 2021-12-01 00:00:00  1.021086e+09  905      SCM           9.0
# 325 2021-12-01 00:00:00  1.021087e+09  102      SCM           1.0
# 326 2021-12-01 00:00:00  1.021085e+09  113      SCM           1.0
# 327 2021-12-01 00:00:00  1.021085e+09  113      SCM           1.0
# 328 2021-12-01 00:00:00  1.021085e+09  113      SCM           8.0
#
#                 Time In        Time Checked       Pharmacist_Checked  \
# 0   2021-06-01 09:13:00 2021-06-01 09:07:17              Ray Hng Yeo
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2589 entries, 0 to 328
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2312 non-null   datetime64[ns]
#  1   Case Number           2312 non-null   float64
#  2   Room                  2312 non-null   object
#  3   TTO Type              2303 non-null   object
#  4   No. of Items          2309 non-null   float64
#  5   Time In               2283 non-null   datetime64[ns]
#  6   Time Checked          2114 non-null   datetime64[ns]
#  7   Pharmacist_Checked    2105 non-null   object
#  8   Time Reached          1969 non-null   datetime64[ns]
#  9   Time Dispensed        1668 non-null   datetime64[ns]
#  10  Pharmacist_Dispensed  1831 non-null   object
#  11  Remarks               421 non-null    object
#  12  Dispatcher            1 non-null      object
#  13  TTO_TAT_Calc          2312 non-null   object
# ...

# %%
df2 = df2.drop(['TTO_TAT_Calc', 'Total number of TTO', 'Status_Time_Met', 'ID', 'Title', 'TTOaddon', 'Item Type', 'Path', 'Unnamed: 23', 'Unnamed: 24'], axis = 1)

# %%
df2
# Out:
#                    Date   Case Number Room TTO Type  No. of Items  \
# 0   2021-06-01 01:00:00  1.021039e+09  953      SCM           3.0
# 1   2021-06-01 01:00:00  1.021039e+09  623      SCM           1.0
# 2   2021-06-01 01:00:00  1.021039e+09  757      SCM           1.0
# 3   2021-06-01 01:00:00  1.021038e+09  916      SCM           4.0
# 4   2021-06-01 01:00:00  1.021039e+09  958      NaN           NaN
# ..                  ...           ...  ...      ...           ...
# 324 2021-12-01 00:00:00  1.021086e+09  905      SCM           9.0
# 325 2021-12-01 00:00:00  1.021087e+09  102      SCM           1.0
# 326 2021-12-01 00:00:00  1.021085e+09  113      SCM           1.0
# 327 2021-12-01 00:00:00  1.021085e+09  113      SCM           1.0
# 328 2021-12-01 00:00:00  1.021085e+09  113      SCM           8.0
#
#                 Time In        Time Checked       Pharmacist_Checked  \
# 0   2021-06-01 09:13:00 2021-06-01 09:07:17              Ray Hng Yeo
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2589 entries, 0 to 328
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2312 non-null   datetime64[ns]
#  1   Case Number           2312 non-null   float64
#  2   Room                  2312 non-null   object
#  3   TTO Type              2303 non-null   object
#  4   No. of Items          2309 non-null   float64
#  5   Time In               2283 non-null   datetime64[ns]
#  6   Time Checked          2114 non-null   datetime64[ns]
#  7   Pharmacist_Checked    2105 non-null   object
#  8   Time Reached          1969 non-null   datetime64[ns]
#  9   Time Dispensed        1668 non-null   datetime64[ns]
#  10  Pharmacist_Dispensed  1831 non-null   object
#  11  Remarks               421 non-null    object
#  12  Dispatcher            1 non-null      object
#  13  status_CheckedTTO     2312 non-null   object
# ...

# %%
#df2['Date'].notnull()

# %%
#indexes = df2[(df2['Time'] == 0) & (df2['Case Number'] > 0)].index
#df2.drop(indexes,inplace=True)
#df2

# %%
df2.to_csv("GEH TTO TAT (June-Dec 2021).csv", index = None, header=True)

# %% [markdown]
# # Combine 2 dataset

# %%
df1 = pd.read_csv('GEH TTO TAT (April-May 2021).csv')
df1.head()
# Out:
#                  Date      Case No Room No Ward SCM / Handwritten TTO   \
# 0  2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 1  2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 2  2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 3  2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 4  2021-04-01 00:00:00  1021023455     909   9E                    SCM
#
#   No. of items Time in / Verified Time checked Checked by Time to meet  \
# 0            2           08:59:00     09:04:00        LET     09:44:00
# 1            3           09:05:00     09:26:00        LET     09:50:00
# 2            4           09:07:00     09:19:00        LET     09:52:00
# 3            2           09:11:00     09:22:00      ELISE     09:56:00
# 4            5           09:36:00     10:02:00      ELISE     10:21:00
#
#   Time reached   Time Counselled Counselled by Remarks Limo Service   \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    423 non-null    object
#  1   Case No                 497 non-null    int64
#  2   Room No                 497 non-null    object
#  3   Ward                    497 non-null    object
#  4   SCM / Handwritten TTO   497 non-null    object
#  5   No. of items            497 non-null    object
#  6   Time in / Verified      491 non-null    object
#  7   Time checked            471 non-null    object
#  8   Checked by              471 non-null    object
#  9   Time to meet            497 non-null    object
#  10  Time reached            434 non-null    object
#  11   Time Counselled        390 non-null    object
#  12  Counselled by           423 non-null    object
#  13  Remarks                 154 non-null    object
# ...

# %%
df1 = df1.drop([' Time Counselled', 'Counselled by', 'Unnamed: 17'], axis = 1)
df1 = df1.drop(df1.columns[[14]], axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    423 non-null    object
#  1   Case No                 497 non-null    int64
#  2   Room No                 497 non-null    object
#  3   Ward                    497 non-null    object
#  4   SCM / Handwritten TTO   497 non-null    object
#  5   No. of items            497 non-null    object
#  6   Time in / Verified      491 non-null    object
#  7   Time checked            471 non-null    object
#  8   Checked by              471 non-null    object
#  9   Time to meet            497 non-null    object
#  10  Time reached            434 non-null    object
#  11  Remarks                 154 non-null    object
#  12  Limo Service            1 non-null      object
#  13  Timings (Checked)       489 non-null    object
# ...

# %%
df1 = df1.drop(df1.columns[[12]], axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    423 non-null    object
#  1   Case No                 497 non-null    int64
#  2   Room No                 497 non-null    object
#  3   Ward                    497 non-null    object
#  4   SCM / Handwritten TTO   497 non-null    object
#  5   No. of items            497 non-null    object
#  6   Time in / Verified      491 non-null    object
#  7   Time checked            471 non-null    object
#  8   Checked by              471 non-null    object
#  9   Time to meet            497 non-null    object
#  10  Time reached            434 non-null    object
#  11  Remarks                 154 non-null    object
#  12  Timings (Checked)       489 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 50.6+ KB

# %%
df1.head()
# Out:
#                  Date      Case No Room No Ward SCM / Handwritten TTO   \
# 0  2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 1  2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 2  2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 3  2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 4  2021-04-01 00:00:00  1021023455     909   9E                    SCM
#
#   No. of items Time in / Verified Time checked Checked by Time to meet  \
# 0            2           08:59:00     09:04:00        LET     09:44:00
# 1            3           09:05:00     09:26:00        LET     09:50:00
# 2            4           09:07:00     09:19:00        LET     09:52:00
# 3            2           09:11:00     09:22:00      ELISE     09:56:00
# 4            5           09:36:00     10:02:00      ELISE     10:21:00
#
#   Time reached  Remarks Timings (Checked)
# 0      09:29:00     NaN          00:05:00
# ...

# %%
df2 = pd.read_csv('GEH TTO TAT (June-Dec 2021).csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589 entries, 0 to 2588
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2312 non-null   object
#  1   Case Number           2312 non-null   float64
#  2   Room                  2312 non-null   object
#  3   TTO Type              2303 non-null   object
#  4   No. of Items          2309 non-null   float64
#  5   Time In               2283 non-null   object
#  6   Time Checked          2114 non-null   object
#  7   Pharmacist_Checked    2105 non-null   object
#  8   Time Reached          1969 non-null   object
#  9   Time Dispensed        1668 non-null   object
#  10  Pharmacist_Dispensed  1831 non-null   object
#  11  Remarks               421 non-null    object
#  12  Dispatcher            1 non-null      object
#  13  status_CheckedTTO     2312 non-null   object
#  14  status_TTOReached     2312 non-null   object
# ...

# %%
df2.head()
# Out:
#                   Date   Case Number Room TTO Type  No. of Items  \
# 0  2021-06-01 01:00:00  1.021039e+09  953      SCM           3.0
# 1  2021-06-01 01:00:00  1.021039e+09  623      SCM           1.0
# 2  2021-06-01 01:00:00  1.021039e+09  757      SCM           1.0
# 3  2021-06-01 01:00:00  1.021038e+09  916      SCM           4.0
# 4  2021-06-01 01:00:00  1.021039e+09  958      NaN           NaN
#
#                Time In         Time Checked       Pharmacist_Checked  \
# 0  2021-06-01 09:13:00  2021-06-01 09:07:17              Ray Hng Yeo
# 1  2021-06-01 09:30:00  2021-06-01 09:38:25              Ray Hng Yeo
# 2  2021-06-01 09:36:00  2021-06-01 09:43:48  Nur Shahida Binte Ahmad
# 3  2021-06-01 09:46:00  2021-06-01 09:49:54  Nur Shahida Binte Ahmad
# 4  2021-06-01 08:55:00  2021-06-01 09:56:00                 Wan Qing
#
#           Time Reached       Time Dispensed Pharmacist_Dispensed  \
# 0  2021-06-01 09:28:26  2021-06-01 09:31:37        Zhao Wan Qing
# ...

# %%
df2 = df2.drop(df2.columns[[12, 13, 14, 15, 16]], axis=1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589 entries, 0 to 2588
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2312 non-null   object
#  1   Case Number           2312 non-null   float64
#  2   Room                  2312 non-null   object
#  3   TTO Type              2303 non-null   object
#  4   No. of Items          2309 non-null   float64
#  5   Time In               2283 non-null   object
#  6   Time Checked          2114 non-null   object
#  7   Pharmacist_Checked    2105 non-null   object
#  8   Time Reached          1969 non-null   object
#  9   Time Dispensed        1668 non-null   object
#  10  Pharmacist_Dispensed  1831 non-null   object
#  11  Remarks               421 non-null    object
#  12  Time                  1932 non-null   float64
# dtypes: float64(3), object(10)
# memory usage: 263.1+ KB

# %%
df1.head()
# Out:
#                  Date      Case No Room No Ward SCM / Handwritten TTO   \
# 0  2021-04-01 00:00:00  1021023186     957   9W                    SCM
# 1  2021-04-01 00:00:00  1021023191     509   5E                    SCM
# 2  2021-04-01 00:00:00  1021023190     508   5E                    SCM
# 3  2021-04-01 00:00:00  1021023367     932   9E                    SCM
# 4  2021-04-01 00:00:00  1021023455     909   9E                    SCM
#
#   No. of items Time in / Verified Time checked Checked by Time to meet  \
# 0            2           08:59:00     09:04:00        LET     09:44:00
# 1            3           09:05:00     09:26:00        LET     09:50:00
# 2            4           09:07:00     09:19:00        LET     09:52:00
# 3            2           09:11:00     09:22:00      ELISE     09:56:00
# 4            5           09:36:00     10:02:00      ELISE     10:21:00
#
#   Time reached  Remarks Timings (Checked)
# 0      09:29:00     NaN          00:05:00
# ...

# %%
df2.head()
# Out:
#                   Date   Case Number Room TTO Type  No. of Items  \
# 0  2021-06-01 01:00:00  1.021039e+09  953      SCM           3.0
# 1  2021-06-01 01:00:00  1.021039e+09  623      SCM           1.0
# 2  2021-06-01 01:00:00  1.021039e+09  757      SCM           1.0
# 3  2021-06-01 01:00:00  1.021038e+09  916      SCM           4.0
# 4  2021-06-01 01:00:00  1.021039e+09  958      NaN           NaN
#
#                Time In         Time Checked       Pharmacist_Checked  \
# 0  2021-06-01 09:13:00  2021-06-01 09:07:17              Ray Hng Yeo
# 1  2021-06-01 09:30:00  2021-06-01 09:38:25              Ray Hng Yeo
# 2  2021-06-01 09:36:00  2021-06-01 09:43:48  Nur Shahida Binte Ahmad
# 3  2021-06-01 09:46:00  2021-06-01 09:49:54  Nur Shahida Binte Ahmad
# 4  2021-06-01 08:55:00  2021-06-01 09:56:00                 Wan Qing
#
#           Time Reached       Time Dispensed Pharmacist_Dispensed  \
# 0  2021-06-01 09:28:26  2021-06-01 09:31:37        Zhao Wan Qing
# ...
